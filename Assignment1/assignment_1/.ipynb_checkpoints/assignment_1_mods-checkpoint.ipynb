# %% [markdown]
# <hr style="border-top-width:4px; border-top-color: #2188bf;">
# <img align="right" src="images/Logo_Università_Padova.png" alt="Drawing" style="width: 300px"/>
# <img align="right" src="images/Logo_Physics_of_Data.jpg" alt="Drawing" style="width: 135px"/>
#
# # MAPD (mod.B) Final Project
# # Analysis of Covid-19 papers
#
# ### Authors
# * [Ardino Rocco](https://github.com/RoccoA97) (University of Padua)
# * [Pagano Alice](https://github.com/AlicePagano) (University of Padua)
# * [Valente Alessandro](https://github.com/mastrovalentz) (University of Padua)
#
# <hr style="border-top-width:4px; border-top-color: #2188bf;">

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <hr style="border-top-width:4px; border-top-color: #2188bf;">
#
# # Index <a class="anchor" id="MAPD_B_FP.i"></a>
#
# * 1. [**Introduction**](#MAPD_B_FP.1.)
# * 2. [**Word counter distributed algorithm**](#MAPD_B_FP.2.)
#
# <hr style="border-top-width:4px; border-top-color: #2188bf;">

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <hr style="border-top-width:4px; border-top-color: #2188bf;">
#
# ## 1. - Introduction <a class="anchor" id="MAPD_B_FP.1."></a>
# * [Index](#MAPD_B_FP.i)

# %%
from dask.distributed import Client
from dask import delayed

client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:40751' processes=4 threads=12, memory=16.80 GB>

# %%
import dask.bag as db
import os
import json

# %%
filename = os.path.join('data', 'papers_in_json_singleline', '*.json')
lines = db.read_text(filename)
js = lines.map(json.loads).repartition(10)

# %%
body = js.pluck("body_text")

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk import word_tokenize

tokenizer = RegexpTokenizer(r'\w+')
stop_words = set(stopwords.words('english'))


def merge(record):
    text=''
    for rec in record:
        text+=rec['text']
    return text

texts = js.pluck("body_text").map(merge)
texts.take(2, npartitions=2)

def clean_func(text):

    text_tokens = word_tokenize(text)
    tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]

    return tokens_without_sw

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk import word_tokenize

tokenizer = RegexpTokenizer(r'\w+')

no_words={"i", "as", "or", "it"}
def clean_func(text):

    def merge_text(text,stop_words):
        new_sentence =''
        for w in text:
            if w.lower() not in stop_words: 
                new_sentence += w 
                new_sentence += " "
        return new_sentence

    stop_words = set(stopwords.words('english'))
    result = word_tokenize(text)
    result = merge_text(result,stop_words.union(no_words))
    result = tokenizer.tokenize(result)
    return result

text_clean = texts.map(clean_func)

# %%
from collections import Counter

def count_words(text):
    counts = dict(zip(Counter(text).keys(), Counter(text).values()))
    wList = [{"word":x , "counts": y} for x,y in counts.items()]
    return wList

def order_words(text):
    return {k: v for k, v in sorted(text.items(), key=lambda item: item[1], reverse=True)}

words = text_clean.map(count_words)
#words_ordered = words.map(order_words)


words.take(1)
# Out:
# ([{'word': 'Plasmodium', 'counts': 7},
#   {'word': 'falciparum', 'counts': 29},
#   {'word': 'causes', 'counts': 2},
#   {'word': 'malignant', 'counts': 1},
#   {'word': 'malaria', 'counts': 6},
#   {'word': 'cerebral', 'counts': 1},
#   {'word': 'CM', 'counts': 1},
#   {'word': 'pregnancy', 'counts': 1},
#   {'word': 'associated', 'counts': 5},
#   {'word': 'PAM', 'counts': 1},
#   {'word': '1', 'counts': 25},
#   {'word': '2', 'counts': 36},
#   {'word': 'cause', 'counts': 1},
#   {'word': 'death', 'counts': 1},
#   {'word': '435', 'counts': 1},
#   {'word': '000', 'counts': 1},
#   {'word': 'individuals', 'counts': 1},
#   {'word': 'annually', 'counts': 1},
#   {'word': '3', 'counts': 21},
#   {'word': 'erythrocyte', 'counts': 1},
#   {'word': 'membrane', 'counts': 1},
#   {'word': 'protein', 'counts': 21},
#   {'word': 'PfEMP1', 'counts': 2},
#   {'word': 'encoded', 'counts': 2},
#   {'word': 'var', 'counts': 59},
#   {'word': 'gene', 'counts': 36},
#   {'word': 'family', 'counts': 7},
#   {'word': 'comprising', 'counts': 2},
#   {'word': 'approximately', 'counts': 2},
#   {'word': '60', 'counts': 5},
#   {'word': 'members', 'counts': 4},
#   {'word': 'major', 'counts': 5},
#   {'word': 'virulence', 'counts': 3},
#   {'word': 'factor', 'counts': 2},
#   {'word': 'involved', 'counts': 9},
#   {'word': 'antigenic', 'counts': 3},
#   {'word': 'variation', 'counts': 7},
#   {'word': 'clinical', 'counts': 1},
#   {'word': 'pathogenicity', 'counts': 1},
#   {'word': '4', 'counts': 14},
#   {'word': '5', 'counts': 36},
#   {'word': 'remarkable', 'counts': 1},
#   {'word': 'expression', 'counts': 42},
#   {'word': 'mutually', 'counts': 2},
#   {'word': 'exclusive', 'counts': 2},
#   {'word': 'parasite', 'counts': 32},
#   {'word': 'time', 'counts': 5},
#   {'word': 'one', 'counts': 7},
#   {'word': 'genes', 'counts': 40},
#   {'word': 'expressed', 'counts': 12},
#   {'word': 'remaining', 'counts': 1},
#   {'word': 'silenced', 'counts': 1},
#   {'word': '6', 'counts': 13},
#   {'word': '7', 'counts': 5},
#   {'word': 'generation', 'counts': 1},
#   {'word': 'P', 'counts': 41},
#   {'word': 'able', 'counts': 1},
#   {'word': 'express', 'counts': 1},
#   {'word': 'different', 'counts': 12},
#   {'word': 'switches', 'counts': 1},
#   {'word': 'lead', 'counts': 3},
#   {'word': 'results', 'counts': 13},
#   {'word': 'immune', 'counts': 2},
#   {'word': 'evasion', 'counts': 2},
#   {'word': 'chronic', 'counts': 1},
#   {'word': 'infection', 'counts': 1},
#   {'word': '8', 'counts': 4},
#   {'word': '9', 'counts': 8},
#   {'word': '10', 'counts': 11},
#   {'word': '11', 'counts': 7},
#   {'word': 'process', 'counts': 12},
#   {'word': 'proven', 'counts': 1},
#   {'word': 'mediated', 'counts': 2},
#   {'word': 'epigenetic', 'counts': 2},
#   {'word': 'mechanisms', 'counts': 2},
#   {'word': 'including', 'counts': 6},
#   {'word': 'chromatin', 'counts': 20},
#   {'word': 'modification', 'counts': 3},
#   {'word': 'nuclear', 'counts': 8},
#   {'word': 'architecture', 'counts': 2},
#   {'word': 'relocation', 'counts': 1},
#   {'word': '12', 'counts': 5},
#   {'word': '13', 'counts': 5},
#   {'word': 'It', 'counts': 2},
#   {'word': 'shown', 'counts': 3},
#   {'word': 'single', 'counts': 8},
#   {'word': 'active', 'counts': 4},
#   {'word': 'enriched', 'counts': 2},
#   {'word': 'euchromatic', 'counts': 1},
#   {'word': 'modifications', 'counts': 2},
#   {'word': 'histone', 'counts': 12},
#   {'word': 'lysine', 'counts': 4},
#   {'word': 'acetylation', 'counts': 2},
#   {'word': 'H3K9ac', 'counts': 2},
#   {'word': 'trimethylation', 'counts': 3},
#   {'word': 'H3K4me3', 'counts': 1},
#   {'word': 'particularly', 'counts': 3},
#   {'word': 'near', 'counts': 1},
#   {'word': 'transcriptional', 'counts': 7},
#   {'word': 'start', 'counts': 2},
#   {'word': 'site', 'counts': 5},
#   {'word': 'TSS', 'counts': 1},
#   {'word': '14', 'counts': 2},
#   {'word': 'silent', 'counts': 4},
#   {'word': 'usually', 'counts': 3},
#   {'word': 'heterochromatin', 'counts': 4},
#   {'word': 'marker', 'counts': 2},
#   {'word': 'lysine9', 'counts': 1},
#   {'word': 'H3K9me3', 'counts': 1},
#   {'word': 'UTR', 'counts': 2},
#   {'word': 'coding', 'counts': 1},
#   {'word': 'sequence', 'counts': 7},
#   {'word': '15', 'counts': 7},
#   {'word': '16', 'counts': 1},
#   {'word': '17', 'counts': 1},
#   {'word': 'modifying', 'counts': 3},
#   {'word': 'enzymes', 'counts': 2},
#   {'word': 'PfMYST', 'counts': 2},
#   {'word': 'PfGCN5', 'counts': 2},
#   {'word': 'PfSIR2', 'counts': 1},
#   {'word': 'PfSET', 'counts': 1},
#   {'word': 'considered', 'counts': 1},
#   {'word': 'important', 'counts': 2},
#   {'word': 'control', 'counts': 3},
#   {'word': 'reversible', 'counts': 1},
#   {'word': 'according', 'counts': 4},
#   {'word': 'previous', 'counts': 4},
#   {'word': 'studies', 'counts': 6},
#   {'word': 'putative', 'counts': 3},
#   {'word': 'acetyltransferases', 'counts': 1},
#   {'word': 'HATs', 'counts': 1},
#   {'word': 'capable', 'counts': 1},
#   {'word': 'acetylating', 'counts': 1},
#   {'word': 'multiple', 'counts': 5},
#   {'word': 'lysines', 'counts': 1},
#   {'word': 'H4', 'counts': 1},
#   {'word': '18', 'counts': 4},
#   {'word': '19', 'counts': 3},
#   {'word': 'orthologue', 'counts': 1},
#   {'word': 'yeast', 'counts': 2},
#   {'word': 'HAT', 'counts': 1},
#   {'word': 'influences', 'counts': 1},
#   {'word': 'H3K9', 'counts': 1},
#   {'word': 'K14', 'counts': 1},
#   {'word': 'essential', 'counts': 3},
#   {'word': 'marks', 'counts': 1},
#   {'word': 'activation', 'counts': 3},
#   {'word': '20', 'counts': 5},
#   {'word': 'Two', 'counts': 2},
#   {'word': 'paralogues', 'counts': 1},
#   {'word': 'class', 'counts': 1},
#   {'word': 'III', 'counts': 1},
#   {'word': 'HDAC', 'counts': 1},
#   {'word': 'deacetylases', 'counts': 1},
#   {'word': 'Sir2', 'counts': 1},
#   {'word': 'play', 'counts': 6},
#   {'word': 'key', 'counts': 5},
#   {'word': 'roles', 'counts': 3},
#   {'word': 'maintaining', 'counts': 1},
#   {'word': '21', 'counts': 3},
#   {'word': '22', 'counts': 2},
#   {'word': 'PfSir2A', 'counts': 1},
#   {'word': 'deacetylates', 'counts': 1},
#   {'word': 'H3K14ac', 'counts': 1},
#   {'word': 'H4K16ac', 'counts': 1},
#   {'word': '23', 'counts': 1},
#   {'word': 'silencing', 'counts': 13},
#   {'word': 'subtelomeric', 'counts': 3},
#   {'word': 'upsA', 'counts': 20},
#   {'word': 'upsEand', 'counts': 1},
#   {'word': 'upsC', 'counts': 13},
#   {'word': 'subtype', 'counts': 2},
#   {'word': 'vars', 'counts': 33},
#   {'word': 'contrast', 'counts': 3},
#   {'word': 'PfSir2B', 'counts': 2},
#   {'word': 'silences', 'counts': 2},
#   {'word': 'upsB', 'counts': 22},
#   {'word': 'Furthermore', 'counts': 2},
#   {'word': 'total', 'counts': 3},
#   {'word': 'ten', 'counts': 1},
#   {'word': 'methyltransferases', 'counts': 1},
#   {'word': 'HKMTs', 'counts': 1},
#   {'word': 'belonging', 'counts': 1},
#   {'word': 'SET', 'counts': 3},
#   {'word': 'domain', 'counts': 11},
#   {'word': 'found', 'counts': 5},
#   {'word': '24', 'counts': 6},
#   {'word': '25', 'counts': 3},
#   {'word': 'PfSET10', 'counts': 2},
#   {'word': 'localizes', 'counts': 1},
#   {'word': 'specialized', 'counts': 1},
#   {'word': 'region', 'counts': 3},
#   {'word': 'periphery', 'counts': 3},
#   {'word': 'H3K4me4', 'counts': 1},
#   {'word': 'transferase', 'counts': 1},
#   {'word': '26', 'counts': 2},
#   {'word': 'variant', 'counts': 3},
#   {'word': 'PfSETvs', 'counts': 1},
#   {'word': 'controls', 'counts': 4},
#   {'word': 'H3K36me3', 'counts': 2},
#   {'word': '27', 'counts': 2},
#   {'word': 'Moreover', 'counts': 1},
#   {'word': 'subnuclear', 'counts': 1},
#   {'word': 'contributes', 'counts': 1},
#   {'word': 'regulation', 'counts': 7},
#   {'word': 'default', 'counts': 1},
#   {'word': 'since', 'counts': 1},
#   {'word': 'located', 'counts': 1},
#   {'word': '28', 'counts': 2},
#   {'word': 'However', 'counts': 5},
#   {'word': 'promoters', 'counts': 1},
#   {'word': 'seem', 'counts': 1},
#   {'word': 'occupy', 'counts': 1},
#   {'word': 'privileged', 'counts': 1},
#   {'word': 'making', 'counts': 1},
#   {'word': 'permissive', 'counts': 1},
#   {'word': 'transcribe', 'counts': 1},
#   {'word': 'PF11_0091', 'counts': 1},
#   {'word': 'ApiAP2', 'counts': 2},
#   {'word': 'member', 'counts': 2},
#   {'word': 'binds', 'counts': 2},
#   {'word': 'conserved', 'counts': 3},
#   {'word': 'motif', 'counts': 1},
#   {'word': 'introns', 'counts': 1},
#   {'word': 'mediates', 'counts': 1},
#   {'word': 'episomal', 'counts': 3},
#   {'word': 'anchoring', 'counts': 1},
#   {'word': 'towards', 'counts': 4},
#   {'word': 'recruiting', 'counts': 1},
#   {'word': 'actin', 'counts': 9},
#   {'word': 'complex', 'counts': 9},
#   {'word': 'polymerized', 'counts': 1},
#   {'word': 'de', 'counts': 1},
#   {'word': 'represses', 'counts': 1},
#   {'word': '29', 'counts': 2},
#   {'word': 'On', 'counts': 2},
#   {'word': 'hand', 'counts': 2},
#   {'word': 'various', 'counts': 2},
#   {'word': 'trans', 'counts': 2},
#   {'word': 'factors', 'counts': 7},
#   {'word': 'intimately', 'counts': 1},
#   {'word': 'regulating', 'counts': 6},
#   {'word': 'structure', 'counts': 3},
#   {'word': 'activity', 'counts': 2},
#   {'word': 'PfAlbas', 'counts': 1},
#   {'word': 'contribute', 'counts': 1},
#   {'word': '30', 'counts': 8},
#   {'word': 'PfSIP2', 'counts': 1},
#   {'word': 'another', 'counts': 2},
#   {'word': 'recruitment', 'counts': 1},
#   {'word': 'organization', 'counts': 1},
#   {'word': 'binding', 'counts': 5},
#   {'word': 'SPE2', 'counts': 1},
#   {'word': '31', 'counts': 1},
#   {'word': 'induces', 'counts': 2},
#   {'word': 'comprehensive', 'counts': 1},
#   {'word': 'promoter', 'counts': 3},
#   {'word': 'Particularly', 'counts': 1},
#   {'word': 'four', 'counts': 3},
#   {'word': 'classes', 'counts': 1},
#   {'word': 'ATP', 'counts': 2},
#   {'word': 'dependent', 'counts': 5},
#   {'word': 'remodelers', 'counts': 1},
#   {'word': 'facilitating', 'counts': 3},
#   {'word': 'spatial', 'counts': 1},
#   {'word': 'temporal', 'counts': 2},
#   {'word': 'remodeling', 'counts': 8},
#   {'word': 'remodeler', 'counts': 2},
#   {'word': 'families', 'counts': 1},
#   {'word': 'consist', 'counts': 2},
#   {'word': 'SWI2', 'counts': 2},
#   {'word': 'SNF2family', 'counts': 1},
#   {'word': 'ATPase', 'counts': 3},
#   {'word': 'subunit', 'counts': 1},
#   {'word': 'featuring', 'counts': 1},
#   {'word': '32', 'counts': 3},
#   {'word': '33', 'counts': 1},
#   {'word': 'includes', 'counts': 2},
#   {'word': 'HSA', 'counts': 2},
#   {'word': 'helicase', 'counts': 1},
#   {'word': 'SANT', 'counts': 2},
#   {'word': 'post', 'counts': 2},
#   {'word': 'C', 'counts': 27},
#   {'word': 'terminal', 'counts': 3},
#   {'word': 'bromodomain', 'counts': 1},
#   {'word': 'subunits', 'counts': 1},
#   {'word': 'carry', 'counts': 2},
#   {'word': 'extra', 'counts': 1},
#   {'word': 'domains', 'counts': 3},
#   {'word': 'hBAF155', 'counts': 1},
#   {'word': '170', 'counts': 1},
#   {'word': 'SWIRM', 'counts': 1},
#   {'word': 'hBAF60', 'counts': 1},
#   {'word': 'SWIB', 'counts': 10},
#   {'word': 'human', 'counts': 4},
#   {'word': 'polybromo', 'counts': 1},
#   {'word': 'bromodomains', 'counts': 1},
#   {'word': 'BAF60b', 'counts': 4},
#   {'word': 'generally', 'counts': 2},
#   {'word': 'known', 'counts': 4},
#   {'word': 'SWI', 'counts': 13},
#   {'word': 'B', 'counts': 5},
#   {'word': 'alternative', 'counts': 3},
#   {'word': 'form', 'counts': 3},
#   {'word': 'SNF', 'counts': 10},
#   {'word': 'Complex', 'counts': 2},
#   {'word': '34', 'counts': 2},
#   {'word': 'BAF60a', 'counts': 3},
#   {'word': 'responsible', 'counts': 2},
#   {'word': 'cell', 'counts': 3},
#   {'word': 'cycle', 'counts': 19},
#   {'word': 'halting', 'counts': 2},
#   {'word': 'ability', 'counts': 1},
#   {'word': 'tune', 'counts': 2},
#   {'word': 'balance', 'counts': 2},
#   {'word': 'repair', 'counts': 2},
#   {'word': 'apoptosis', 'counts': 4},
#   {'word': 'induction', 'counts': 2},
#   {'word': '35', 'counts': 4},
#   {'word': '36', 'counts': 3},
#   {'word': '37', 'counts': 5},
#   {'word': 'Recently', 'counts': 1},
#   {'word': 'related', 'counts': 5},
#   {'word': 'matrix', 'counts': 2},
#   {'word': 'regulator', 'counts': 3},
#   {'word': 'PfSWIB', 'counts': 118},
#   {'word': 'GenBank', 'counts': 2},
#   {'word': 'PF3D7_0611400', 'counts': 1},
#   {'word': 'characterized', 'counts': 4},
#   {'word': 'MDM2', 'counts': 6},
#   {'word': 'identified', 'counts': 4},
#   {'word': 'might', 'counts': 7},
#   {'word': 'trigger', 'counts': 1},
#   {'word': 'stage', 'counts': 25},
#   {'word': 'specific', 'counts': 12},
#   {'word': 'PCD', 'counts': 2},
#   {'word': 'transient', 'counts': 2},
#   {'word': 'localization', 'counts': 2},
#   {'word': 'removal', 'counts': 3},
#   {'word': 'parasites', 'counts': 24},
#   {'word': '38', 'counts': 7},
#   {'word': 'revealed', 'counts': 6},
#   {'word': 'crucial', 'counts': 3},
#   {'word': 'survival', 'counts': 6},
#   {'word': 'growth', 'counts': 7},
#   {'word': 'also', 'counts': 8},
#   {'word': 'profound', 'counts': 2},
#   {'word': 'effects', 'counts': 2},
#   {'word': 'interacting', 'counts': 2},
#   {'word': 'unknown', 'counts': 3},
#   {'word': 'proteins', 'counts': 10},
#   {'word': '39', 'counts': 4},
#   {'word': '40', 'counts': 7},
#   {'word': 'remains', 'counts': 2},
#   {'word': 'unclear', 'counts': 2},
#   {'word': 'whether', 'counts': 2},
#   {'word': 'especially', 'counts': 4},
#   {'word': 'functional', 'counts': 3},
#   {'word': 'properties', 'counts': 1},
#   {'word': 'To', 'counts': 4},
#   {'word': 'address', 'counts': 1},
#   {'word': 'molecular', 'counts': 2},
#   {'word': 'mechanism', 'counts': 2},
#   {'word': 'propose', 'counts': 1},
#   {'word': 'new', 'counts': 2},
#   {'word': 'conditional', 'counts': 2},
#   {'word': 'knockdown', 'counts': 5},
#   {'word': 'system', 'counts': 6},
#   {'word': 'study', 'counts': 12},
#   {'word': 'function', 'counts': 6},
#   {'word': 'dysfunction', 'counts': 2},
#   {'word': 'significant', 'counts': 8},
#   {'word': 'downregulation', 'counts': 3},
#   {'word': 'partial', 'counts': 12},
#   {'word': 'ring', 'counts': 14},
#   {'word': 'line', 'counts': 20},
#   {'word': 'well', 'counts': 9},
#   {'word': 'aberrant', 'counts': 2},
#   {'word': 'certain', 'counts': 3},
#   {'word': 'mature', 'counts': 6},
#   {'word': '48', 'counts': 5},
#   {'word': 'h', 'counts': 12},
#   {'word': 'life', 'counts': 13},
#   {'word': 'reversion', 'counts': 1},
#   {'word': 'suggesting', 'counts': 5},
#   {'word': 'role', 'counts': 5},
#   {'word': 'addition', 'counts': 4},
#   {'word': 'could', 'counts': 10},
#   {'word': 'affect', 'counts': 1},
#   {'word': 'development', 'counts': 1},
#   {'word': 'provides', 'counts': 1},
#   {'word': 'better', 'counts': 2},
#   {'word': 'understanding', 'counts': 2},
#   {'word': 'regulatory', 'counts': 2},
#   {'word': 'complexes', 'counts': 4},
#   {'word': 'CRCs', 'counts': 2},
#   {'word': 'clonal', 'counts': 3},
#   {'word': 'insight', 'counts': 1},
#   {'word': 'contributing', 'counts': 2},
#   {'word': 'pathogenesis', 'counts': 2},
#   {'word': 'lines', 'counts': 32},
#   {'word': '3D7', 'counts': 21},
#   {'word': 'first', 'counts': 6},
#   {'word': 'thawed', 'counts': 2},
#   {'word': 'established', 'counts': 1},
#   {'word': 'continuous', 'counts': 2},
#   {'word': 'cultivation', 'counts': 2},
#   {'word': 'vitro', 'counts': 8},
#   {'word': 'standard', 'counts': 2},
#   {'word': 'procedures', 'counts': 1},
#   {'word': '41', 'counts': 1},
#   {'word': 'follows', 'counts': 3},
#   {'word': 'isolates', 'counts': 1},
#   {'word': 'cultured', 'counts': 4},
#   {'word': 'RPMI', 'counts': 1},
#   {'word': '1640', 'counts': 1},
#   {'word': 'medium', 'counts': 4},
#   {'word': 'Invitrogen', 'counts': 3},
#   {'word': 'Thermo', 'counts': 3},
#   {'word': 'Fisher', 'counts': 3},
#   {'word': 'Scientific', 'counts': 4},
#   {'word': 'Carlsbad', 'counts': 3},
#   {'word': 'CA', 'counts': 5},
#   {'word': 'USA', 'counts': 7},
#   {'word': 'containing', 'counts': 4},
#   {'word': 'mM', 'counts': 4},
#   {'word': 'Hepes', 'counts': 1},
#   {'word': 'l', 'counts': 1},
#   {'word': 'glutamine', 'counts': 1},
#   {'word': '0', 'counts': 36},
#   {'word': 'hypoxanthine', 'counts': 1},
#   {'word': 'Sigma', 'counts': 2},
#   {'word': 'Aldrich', 'counts': 2},
#   {'word': 'Shanghai', 'counts': 3},
#   {'word': 'China', 'counts': 3},
#   {'word': 'mg', 'counts': 1},
#   {'word': 'ml', 'counts': 3},
#   {'word': 'gentamicin', 'counts': 1},
#   {'word': 'Albumax', 'counts': 1},
#   {'word': 'II', 'counts': 4},
#   {'word': 'serum', 'counts': 1},
#   {'word': 'type', 'counts': 3},
#   {'word': 'AB', 'counts': 1},
#   {'word': 'Changhai', 'counts': 1},
#   {'word': 'Hospital', 'counts': 1},
#   {'word': 'Second', 'counts': 1},
#   {'word': 'Military', 'counts': 1},
#   {'word': 'Medical', 'counts': 1},
#   {'word': 'University', 'counts': 1},
#   {'word': 'Cultures', 'counts': 1},
#   {'word': 'grown', 'counts': 1},
#   {'word': 'media', 'counts': 1},
#   {'word': 'O', 'counts': 1},
#   {'word': 'erythrocytes', 'counts': 1},
#   {'word': 'hematocrit', 'counts': 1},
#   {'word': 'CO', 'counts': 1},
#   {'word': '92', 'counts': 1},
#   {'word': 'N', 'counts': 2},
#   {'word': 'obtain', 'counts': 2},
#   {'word': 'tightly', 'counts': 2},
#   {'word': 'synchronized', 'counts': 5},
#   {'word': 'percoll', 'counts': 2},
#   {'word': 'sorbitol', 'counts': 3},
#   {'word': 'synchronization', 'counts': 1},
#   {'word': 'method', 'counts': 2},
#   {'word': 'performed', 'counts': 13},
#   {'word': '42', 'counts': 1},
#   {'word': '43', 'counts': 1},
#   {'word': 'brief', 'counts': 2},
#   {'word': 'schizonts', 'counts': 1},
#   {'word': 'isolated', 'counts': 1},
#   {'word': 'cushion', 'counts': 1},
#   {'word': 'allowed', 'counts': 1},
#   {'word': 'invade', 'counts': 1},
#   {'word': 'fresh', 'counts': 1},
#   {'word': 'RBCs', 'counts': 1},
#   {'word': 'resulting', 'counts': 4},
#   {'word': 'rings', 'counts': 2},
#   {'word': 'subjected', 'counts': 3},
#   {'word': 'treatment', 'counts': 3},
#   {'word': 'min', 'counts': 7},
#   {'word': 'repeated', 'counts': 2},
#   {'word': 'twice', 'counts': 2},
#   {'word': 'culture', 'counts': 7},
#   {'word': 'washed', 'counts': 1},
#   {'word': 're', 'counts': 6},
#   {'word': 'suspended', 'counts': 2},
#   {'word': 'complete', 'counts': 1},
#   {'word': 'RBC', 'counts': 2},
#   {'word': 'final', 'counts': 5},
#   {'word': 'All', 'counts': 1},
#   {'word': 'transfected', 'counts': 8},
#   {'word': 'originated', 'counts': 1},
#   {'word': 'clone', 'counts': 13},
#   {'word': 'DNA', 'counts': 4},
#   {'word': 'extraction', 'counts': 1},
#   {'word': 'using', 'counts': 13},
#   {'word': 'QIAamp', 'counts': 1},
#   {'word': 'Mini', 'counts': 1},
#   {'word': 'Kit', 'counts': 1},
#   {'word': 'Qiagen', 'counts': 1},
#   {'word': 'Hilden', 'counts': 1},
#   {'word': 'Germany', 'counts': 1},
#   {'word': 'high', 'counts': 3},
#   {'word': 'fidelity', 'counts': 1},
#   {'word': 'KOD', 'counts': 1},
#   {'word': 'plus', 'counts': 1},
#   {'word': 'Neo', 'counts': 1},
#   {'word': 'enzyme', 'counts': 1},
#   {'word': 'Toyobo', 'counts': 1},
#   {'word': 'Osaka', 'counts': 1},
#   {'word': 'Japan', 'counts': 1},
#   {'word': 'used', 'counts': 16},
#   {'word': 'PCR', 'counts': 12},
#   {'word': 'amplification', 'counts': 4},
#   {'word': 'detect', 'counts': 3},
#   {'word': 'endogenous', 'counts': 5},
#   {'word': 'locus', 'counts': 7},
#   {'word': 'integration', 'counts': 6},
#   {'word': 'HA', 'counts': 21},
#   {'word': 'FKBP', 'counts': 25},
#   {'word': 'LID', 'counts': 24},
#   {'word': 'reaction', 'counts': 3},
#   {'word': 'conditions', 'counts': 2},
#   {'word': '95', 'counts': 4},
#   {'word': 'followed', 'counts': 4},
#   {'word': 'cycles', 'counts': 4},
#   {'word': '50', 'counts': 3},
#   {'word': '62', 'counts': 2},
#   {'word': 'extension', 'counts': 2},
#   {'word': '65', 'counts': 4},
#   {'word': 'primers', 'counts': 5},
#   {'word': 'listed', 'counts': 3},
#   {'word': 'Additional', 'counts': 26},
#   {'word': 'file', 'counts': 27},
#   {'word': 'Table', 'counts': 9},
#   {'word': 'S1', 'counts': 6},
#   {'word': 'pLN', 'counts': 7},
#   {'word': 'ENR', 'counts': 2},
#   {'word': 'GFP', 'counts': 2},
#   {'word': '44', 'counts': 8},
#   {'word': 'DQ813653', 'counts': 1},
#   {'word': 'modified', 'counts': 5},
#   {'word': 'deleting', 'counts': 1},
#   {'word': 'whole', 'counts': 1},
#   {'word': 'pfenr', 'counts': 1},
#   {'word': 'gfp', 'counts': 1},
#   {'word': 'cassette', 'counts': 1},
#   {'word': 'fragments', 'counts': 1},
#   {'word': 'ApaI', 'counts': 2},
#   {'word': 'BamHI', 'counts': 1},
#   {'word': 'multicloning', 'counts': 2},
#   {'word': 'construct', 'counts': 2},
#   {'word': '6900', 'counts': 1},
#   {'word': 'bp', 'counts': 1},
#   {'word': 'calmodulin', 'counts': 1},
#   {'word': 'CaM', 'counts': 1},
#   {'word': 'fragment', 'counts': 1},
#   {'word': 'initially', 'counts': 4},
#   {'word': 'substituted', 'counts': 1},
#   {'word': 'kb', 'counts': 3},
#   {'word': 'terminus', 'counts': 9},
#   {'word': 'ASCI', 'counts': 1},
#   {'word': 'Three', 'counts': 1},
#   {'word': 'duplicates', 'counts': 1},
#   {'word': 'tag', 'counts': 9},
#   {'word': 'YPYDVPDYA', 'counts': 1},
#   {'word': 'ligated', 'counts': 2},
#   {'word': 'via', 'counts': 2},
#   {'word': 'linker', 'counts': 1},
#   {'word': 'AAAAVDAAAA', 'counts': 1},
#   {'word': 'vector', 'counts': 1},
#   {'word': 'transfect', 'counts': 1},
#   {'word': 'consists', 'counts': 1},
#   {'word': 'three', 'counts': 6},
#   {'word': 'tandem', 'counts': 2},
#   {'word': 'repeat', 'counts': 2},
#   {'word': 'sequences', 'counts': 2},
#   {'word': 'influenza', 'counts': 2},
#   {'word': 'hemagglutinin', 'counts': 2},
#   {'word': 'whereas', 'counts': 4},
#   {'word': 'comprised', 'counts': 2},
#   {'word': 'FK506', 'counts': 1},
#   {'word': 'and', 'counts': 5},
#   {'word': 'rapamycin', 'counts': 2},
#   {'word': 'amino', 'counts': 2},
#   {'word': 'acid', 'counts': 2},
#   {'word': 'degron', 'counts': 3},
#   {'word': 'fused', 'counts': 3},
#   {'word': 'Fig', 'counts': 23},
#   {'word': '1a', 'counts': 2},
#   {'word': '45', 'counts': 5},
#   {'word': 'Transfections', 'counts': 1},
#   {'word': 'ringstage', 'counts': 1},
#   {'word': 'mm', 'counts': 1},
#   {'word': 'BioRad', 'counts': 2},
#   {'word': 'Gene', 'counts': 1},
#   {'word': 'Pulser', 'counts': 1},
#   {'word': 'cuvettes', 'counts': 1},
#   {'word': 'Bio', 'counts': 4},
#   {'word': 'Rad', 'counts': 4},
#   {'word': 'Laboratories', 'counts': 2},
#   {'word': 'Hercules', 'counts': 2},
#   {'word': '94547', 'counts': 2},
#   {'word': 'minimum', 'counts': 2},
#   {'word': '100', 'counts': 2},
#   {'word': 'μg', 'counts': 1},
#   {'word': 'recombinated', 'counts': 1},
#   {'word': 'plasmid', 'counts': 3},
#   {'word': 'purified', 'counts': 2},
#   {'word': 'electroporation', 'counts': 1},
#   {'word': 'GenePulse', 'counts': 1},
#   {'word': 'Xcell', 'counts': 1},
#   {'word': 'electroporator', 'counts': 1},
#   {'word': '310', 'counts': 1},
#   {'word': 'V', 'counts': 1},
#   {'word': 'resistance', 'counts': 3},
#   {'word': '950', 'counts': 1},
#   {'word': 'μF', 'counts': 1},
#   {'word': 'transfection', 'counts': 4},
#   {'word': 'less', 'counts': 2},
#   {'word': 'ms', 'counts': 1},
#   {'word': 'Positive', 'counts': 1},
#   {'word': 'BSD', 'counts': 12},
#   {'word': 'drug', 'counts': 8},
#   {'word': 'selection', 'counts': 2},
#   {'word': 'concentration', 'counts': 2},
#   {'word': 'nM', 'counts': 1},
#   {'word': 'subsequently', 'counts': 12},
#   {'word': 'applied', 'counts': 3},
#   {'word': 'maintained', 'counts': 1},
#   {'word': 'adopted', 'counts': 1},
#   {'word': 'carrying', 'counts': 1},
#   {'word': 'bsd', 'counts': 2},
#   {'word': 'would', 'counts': 2},
#   {'word': 'offer', 'counts': 1},
#   {'word': 'level', 'counts': 8},
#   {'word': 'culturing', 'counts': 4},
#   {'word': 'days', 'counts': 4},
#   {'word': 'subsequent', 'counts': 3},
#   {'word': 'cycling', 'counts': 3},
#   {'word': 'select', 'counts': 1},
#   {'word': 'stable', 'counts': 4},
#   {'word': 'crossover', 'counts': 2},
#   {'word': 'initial', 'counts': 1},
#   {'word': 'obtained', 'counts': 7},
#   {'word': 'mixture', 'counts': 1},
#   {'word': 'integrated', 'counts': 12},
#   {'word': 'Therefore', 'counts': 2},
#   {'word': 'mode', 'counts': 1},
#   {'word': 'screening', 'counts': 8},
#   {'word': 'introduced', 'counts': 2},
#   {'word': 'enrich', 'counts': 2},
#   {'word': 'original', 'counts': 1},
#   {'word': 'absence', 'counts': 7},
#   {'word': 'weeks', 'counts': 4},
#   {'word': 'µg', 'counts': 1},
#   {'word': 'therefore', 'counts': 3},
#   {'word': 'possibly', 'counts': 1},
#   {'word': 'sorted', 'counts': 1},
#   {'word': 'rounds', 'counts': 1},
#   {'word': '1b', 'counts': 2},
#   {'word': 'two', 'counts': 12},
#   {'word': 'events', 'counts': 5},
#   {'word': 'Primers', 'counts': 1},
#   {'word': 'P2', 'counts': 1},
#   {'word': 'P4', 'counts': 1},
#   {'word': 'P5', 'counts': 1},
#   {'word': 'upstream', 'counts': 1},
#   {'word': 'downstream', 'counts': 1},
#   {'word': 'fusion', 'counts': 13},
#   {'word': 'respectively', 'counts': 5},
#   {'word': 'Fn', 'counts': 1},
#   {'word': 'forward', 'counts': 1},
#   {'word': 'primer', 'counts': 2},
#   {'word': 'In', 'counts': 2},
#   {'word': 'order', 'counts': 3},
#   {'word': 'clones', 'counts': 9},
#   {'word': 'utilized', 'counts': 1},
#   {'word': 'assay', 'counts': 4},
#   {'word': 'serial', 'counts': 2},
#   {'word': 'dilution', 'counts': 4},
#   {'word': '96', 'counts': 7},
#   {'word': 'plates', 'counts': 3},
#   {'word': 'detailed', 'counts': 1},
#   {'word': 'previously', 'counts': 5},
#   {'word': '46', 'counts': 1},
#   {'word': 'transfections', 'counts': 2},
#   {'word': 'C2', 'counts': 6},
#   {'word': 'B10', 'counts': 4},
#   {'word': 'detected', 'counts': 2},
#   {'word': 'screened', 'counts': 3},
#   {'word': 'extended', 'counts': 1},
#   {'word': 'testing', 'counts': 3},
#   {'word': 'described', 'counts': 4},
#   {'word': 'see', 'counts': 1},
#   {'word': '94', 'counts': 2},
#   {'word': '54', 'counts': 3},
#   {'word': 'analyze', 'counts': 2},
#   {'word': 'extracts', 'counts': 1},
#   {'word': 'prepared', 'counts': 2},
#   {'word': 'saponin', 'counts': 1},
#   {'word': 'SDS', 'counts': 2},
#   {'word': 'loading', 'counts': 1},
#   {'word': 'buffer', 'counts': 1},
#   {'word': 'separated', 'counts': 1},
#   {'word': 'PAGE', 'counts': 1},
#   {'word': 'gel', 'counts': 1},
#   {'word': 'western', 'counts': 3},
#   {'word': 'blot', 'counts': 2},
#   {'word': 'analysis', 'counts': 16},
#   {'word': 'Total', 'counts': 1},
#   {'word': 'antibody', 'counts': 1},
#   {'word': 'aldolase', 'counts': 1},
#   {'word': '1000', 'counts': 2},
#   {'word': 'Roche', 'counts': 1},
#   {'word': 'Indianapolis', 'counts': 1},
#   {'word': 'positive', 'counts': 1},
#   {'word': 'Rabbit', 'counts': 1},
#   {'word': 'anti', 'counts': 1},
#   {'word': 'Abcam', 'counts': 1},
#   {'word': 'Cambridge', 'counts': 1},
#   {'word': 'UK', 'counts': 1},
#   {'word': 'identify', 'counts': 2},
#   {'word': 'enhanced', 'counts': 1},
#   {'word': 'chemiluminescence', 'counts': 1},
#   {'word': 'ECL', 'counts': 1},
#   {'word': 'blotting', 'counts': 2},
#   {'word': 'kit', 'counts': 1},
#   {'word': 'GE', 'counts': 1},
#   {'word': 'Healthcare', 'counts': 1},
#   {'word': 'Uppsala', 'counts': 1},
#   {'word': 'Sweden', 'counts': 1},
#   {'word': 'develop', 'counts': 1},
#   {'word': 'blots', 'counts': 1},
#   {'word': 'theoretical', 'counts': 1},
#   {'word': 'weight', 'counts': 1},
#   {'word': '92kD', 'counts': 1},
#   {'word': '5kD', 'counts': 1},
#   {'word': '22kD', 'counts': 1},
#   {'word': 'graylevel', 'counts': 1},
#   {'word': 'image', 'counts': 1},
#   {'word': 'procedure', 'counts': 1},
#   {'word': 'implemented', 'counts': 2},
#   {'word': 'ImageJ', 'counts': 1},
#   {'word': 'software', 'counts': 1},
#   {'word': 'Statistical', 'counts': 1},
#   {'word': 'significance', 'counts': 2},
#   {'word': 'determined', 'counts': 2},
#   {'word': '05', 'counts': 11},
#   {'word': '01', 'counts': 3},
#   {'word': 'Synchronized', 'counts': 1},
#   {'word': 'invasion', 'counts': 2},
#   {'word': 'collected', 'counts': 2},
#   {'word': 'diluted', 'counts': 3},
#   {'word': 'parasitemia', 'counts': 8},
#   {'word': 'divided', 'counts': 2},
#   {'word': 'wells', 'counts': 2},
#   {'word': 'cultures', 'counts': 1},
#   {'word': 'plate', 'counts': 1},
#   {'word': 'µl', 'counts': 1},
#   {'word': 'pellets', 'counts': 1},
#   {'word': 'Shield1', 'counts': 1},
#   {'word': 'ethanol', 'counts': 1},
#   {'word': 'Clontech', 'counts': 1},
#   {'word': 'Mountain', 'counts': 1},
#   {'word': 'View', 'counts': 1},
#   {'word': 'added', 'counts': 1},
#   {'word': 'μM', 'counts': 2},
#   {'word': 'Consequently', 'counts': 1},
#   {'word': 'PfSWIBΔ', 'counts': 1},
#   {'word': 'shield1', 'counts': 15},
#   {'word': 'induced', 'counts': 7},
#   {'word': 'sh', 'counts': 6},
#   {'word': 'subject', 'counts': 2},
#   {'word': 'counted', 'counts': 1},
#   {'word': 'every', 'counts': 1},
#   {'word': 'rate', 'counts': 1},
#   {'word': 'compared', 'counts': 6},
#   {'word': 'statistically', 'counts': 1},
#   {'word': 'way', 'counts': 4},
#   {'word': 'ANOVA', 'counts': 2},
#   {'word': 'Bonferroni', 'counts': 1},
#   {'word': 's', 'counts': 5},
#   {'word': 'comparison', 'counts': 4},
#   {'word': 'test', 'counts': 3},
#   {'word': 'Growth', 'counts': 1},
#   {'word': 'curve', 'counts': 3},
#   {'word': 'triplicate', 'counts': 1},
#   {'word': 'For', 'counts': 1},
#   {'word': 'transcription', 'counts': 11},
#   {'word': 'individual', 'counts': 2},
#   {'word': 'pairs', 'counts': 1},
#   {'word': 'published', 'counts': 1},
#   {'word': 'elsewhere', 'counts': 1},
#   {'word': '47', 'counts': 1},
#   {'word': 'S2', 'counts': 4},
#   {'word': 'qPCR', 'counts': 11},
#   {'word': 'assays', 'counts': 2},
#   {'word': 'RNA', 'counts': 18},
#   {'word': 'synchronous', 'counts': 1},
#   {'word': 'extracted', 'counts': 1},
#   {'word': 'TRIzol', 'counts': 1},
#   {'word': 'reagent', 'counts': 1},
#   {'word': 'cDNA', 'counts': 1},
#   {'word': 'accordance', 'counts': 1},
#   {'word': 'manufacturer', 'counts': 1},
#   {'word': 'recommendations', 'counts': 1},
#   {'word': 'Thermofisher', 'counts': 1},
#   {'word': 'fold', 'counts': 10},
#   {'word': 'change', 'counts': 14},
#   {'word': 'experimental', 'counts': 2},
#   {'word': 'reference', 'counts': 3},
#   {'word': 'groups', 'counts': 4},
#   {'word': 'calculated', 'counts': 1},
#   {'word': 'ΔΔCq', 'counts': 1},
#   {'word': 'QuantStudio', 'counts': 1},
#   {'word': 'Flex', 'counts': 1},
#   {'word': 'Real', 'counts': 1},
#   {'word': 'Time', 'counts': 1},
#   {'word': 'System', 'counts': 1},
#   {'word': 'Applied', 'counts': 1},
#   {'word': 'Biosystems', 'counts': 1},
#   {'word': 'Singapore', 'counts': 1},
#   {'word': 'program', 'counts': 1},
#   {'word': 'Seryl', 'counts': 1},
#   {'word': 'tRNA', 'counts': 1},
#   {'word': 'synthetase', 'counts': 1},
#   {'word': 'normalize', 'counts': 1},
#   {'word': 'data', 'counts': 8},
#   {'word': 'statistical', 'counts': 2},
#   {'word': 'tailed', 'counts': 1},
#   {'word': 'Student', 'counts': 1},
#   {'word': 't', 'counts': 1},
#   {'word': 'seq', 'counts': 14},
#   {'word': 'screen', 'counts': 1},
#   {'word': 'differentially', 'counts': 6},
#   {'word': 'carried', 'counts': 1},
#   {'word': 'duplicate', 'counts': 2},
#   {'word': 'genome', 'counts': 5},
#   {'word': 'transcript', 'counts': 1},
#   {'word': 'information', 'counts': 1},
#   {'word': 'PlasmoDB', 'counts': 4},
#   {'word': 'http', 'counts': 2},
#   {'word': 'plasm', 'counts': 2},
#   {'word': 'odb', 'counts': 2},
#   {'word': 'org', 'counts': 2},
#   {'word': 'aligner', 'counts': 1},
#   {'word': 'STAR', 'counts': 1},
#   {'word': 'v2', 'counts': 1},
#   {'word': '3a', 'counts': 1},
#   {'word': '49', 'counts': 1},
#   {'word': 'create', 'counts': 1},
#   {'word': 'catalog', 'counts': 1},
#   {'word': 'based', 'counts': 3},
#   {'word': 'files', 'counts': 1},
#   {'word': 'fasta', 'counts': 2},
#   {'word': 'GFF3', 'counts': 1},
#   {'word': 'annotation', 'counts': 1},
#   {'word': '34_Pfalcipa', 'counts': 1},
#   {'word': 'rum3D7_Genome', 'counts': 1},
#   {'word': '34_Pfalciparum3D7', 'counts': 1},
#   {'word': 'gff', 'counts': 1},
#   {'word': 'FastQC', 'counts': 1},
#   {'word': 'v0', 'counts': 2},
#   {'word': 'quality', 'counts': 2},
#   {'word': 'reads', 'counts': 2},
#   {'word': 'qualified', 'counts': 1},
#   {'word': 'mapped', 'counts': 1},
#   {'word': 'aligned', 'counts': 1},
#   {'word': 'Reads', 'counts': 1},
#   {'word': 'mapping', 'counts': 1},
#   {'word': 'q', 'counts': 1},
#   {'word': 'SAM', 'counts': 1},
#   {'word': 'tools', 'counts': 1},
#   {'word': 'Heatmaps', 'counts': 1},
#   {'word': 'profiles', 'counts': 2},
#   {'word': 'created', 'counts': 1},
#   {'word': 'R', 'counts': 7},
#   {'word': 'package', 'counts': 4},
#   {'word': 'edgeR', 'counts': 3},
#   {'word': 'Hierarchical', 'counts': 1},
#   {'word': 'clustering', 'counts': 4},
#   {'word': 'minus', 'counts': 1},
#   {'word': 'Pearson', 'counts': 1},
#   {'word': 'correlation', 'counts': 5},
#   {'word': 'metric', 'counts': 1},
#   {'word': 'average', 'counts': 1},
#   {'word': 'linkage', 'counts': 1},
#   {'word': 'Line', 'counts': 1},
#   {'word': 'plots', 'counts': 1},
#   {'word': 'generated', 'counts': 1},
#   {'word': 'ggplot2', 'counts': 1},
#   {'word': '51', 'counts': 1},
#   {'word': 'variance', 'counts': 1},
#   {'word': 'like', 'counts': 1},
#   {'word': 'differential', 'counts': 2},
#   {'word': 'summarized', 'counts': 1},
#   {'word': 'read', 'counts': 1},
#   {'word': 'counts', 'counts': 1},
#   {'word': 'per', 'counts': 1},
#   {'word': 'genomic', 'counts': 1},
#   {'word': 'feature', 'counts': 2},
#   {'word': 'Counts', 'counts': 1},
#   {'word': '52', 'counts': 1},
#   {'word': 'ALDEx2', 'counts': 1},
#   {'word': '53', 'counts': 1},
#   {'word': 'greater', 'counts': 1},
#   {'word': 'lower', 'counts': 1},
#   {'word': 'FDR', 'counts': 3},
#   {'word': 'selected', 'counts': 8},
#   {'word': 'filters', 'counts': 1},
#   {'word': 'defining', 'counts': 1},
#   {'word': 'sets', 'counts': 1},
#   {'word': 'harbored', 'counts': 1},
#   {'word': 'antibiotic', 'counts': 1},
#   {'word': 'Blasticidin', 'counts': 2},
#   {'word': 'pink', 'counts': 1},
#   {'word': 'tags', 'counts': 1},
#   {'word': 'red', 'counts': 4},
#   {'word': 'blue', 'counts': 1},
#   {'word': 'green', 'counts': 1},
#   {'word': 'b', 'counts': 1},
#   {'word': 'Drug', 'counts': 1},
#   {'word': 'indicate', 'counts': 1},
#   {'word': 'presence', 'counts': 5},
#   {'word': 'Day', 'counts': 2},
#   {'word': 'details', 'counts': 1},
#   {'word': 'detecting', 'counts': 2},
#   {'word': 'provided', 'counts': 1},
#   {'word': 'Methods', 'counts': 1},
#   {'word': 'Due', 'counts': 1},
#   {'word': 'low', 'counts': 3},
#   {'word': 'proficiency', 'counts': 2},
#   {'word': 'inserting', 'counts': 1},
#   {'word': 'full', 'counts': 2},
#   {'word': 'length', 'counts': 2},
#   {'word': 'cloned', 'counts': 1},
#   {'word': 'recombinant', 'counts': 2},
#   {'word': 'plasmids', 'counts': 1},
#   {'word': 'forming', 'counts': 1},
#   {'word': 'homologous', 'counts': 1},
#   {'word': 'recombination', 'counts': 1},
#   {'word': 'caused', 'counts': 2},
#   {'word': 'event', 'counts': 1},
#   {'word': 'transfecting', 'counts': 1},
#   {'word': 'strain', 'counts': 1},
#   {'word': 'deaminase', 'counts': 1},
#   {'word': 'contains', 'counts': 1},
#   {'word': 'FK506and', 'counts': 1},
#   {'word': 'ligand', 'counts': 1},
#   {'word': 'degradation', 'counts': 3},
#   {'word': 'designed', 'counts': 1},
#   {'word': 'Figure', 'counts': 18},
#   {'word': 'shows', 'counts': 3},
#   {'word': 'identification', 'counts': 1},
#   {'word': 'Stable', 'counts': 1},
#   {'word': 'finally', 'counts': 1},
#   {'word': 'cloning', 'counts': 1},
#   {'word': 'Since', 'counts': 1},
#   {'word': 'exhibited', 'counts': 5},
#   {'word': 'stability', 'counts': 1},
#   {'word': 'reproducibility', 'counts': 1},
#   {'word': 'detection', 'counts': 1},
#   {'word': 'rather', 'counts': 1},
#   {'word': 'present', 'counts': 5},
#   {'word': 'Western', 'counts': 2},
#   {'word': '2000', 'counts': 1},
#   {'word': 'According', 'counts': 5},
#   {'word': 'theoretically', 'counts': 1},
#   {'word': 'small', 'counts': 2},
#   {'word': 'molecule', 'counts': 2},
#   {'word': 'Alternatively', 'counts': 2},
#   {'word': 'thereby', 'counts': 1},
#   {'word': 'substituting', 'counts': 1},
#   {'word': 'triggering', 'counts': 1},
#   {'word': 'rapid', 'counts': 1},
#   {'word': 'may', 'counts': 4},
#   {'word': 'take', 'counts': 1},
#   {'word': 'exert', 'counts': 1},
#   {'word': 'inhibition', 'counts': 1},
#   {'word': 'trophozoite', 'counts': 9},
#   {'word': 'within', 'counts': 8},
#   {'word': 'third', 'counts': 7},
#   {'word': 'samples', 'counts': 3},
#   {'word': 'GCA', 'counts': 3},
#   {'word': '2a', 'counts': 2},
#   {'word': 'indicated', 'counts': 1},
#   {'word': 'although', 'counts': 1},
#   {'word': '114', 'counts': 1},
#   {'word': 'kDa', 'counts': 1},
#   {'word': 'successfully', 'counts': 2},
#   {'word': 'stages', 'counts': 2},
#   {'word': '2b', 'counts': 3},
#   {'word': 'S2a', 'counts': 1},
#   {'word': 'still', 'counts': 1},
#   {'word': 'difference', 'counts': 3},
#   {'word': 'decreased', 'counts': 1},
#   {'word': '890', 'counts': 2},
#   {'word': '0394', 'counts': 2},
#   ...],)

# %%
from operator import add

words = text_clean.map(count_words)

#def amount_sum (x):
#    return np.sum(np.array([y['amount'] for y in x['transactions']]))
#
#def incr_amount(tot, x):
#    return tot+amount_sum(x)

def incr_amount(tot, x):
    return tot+1

am = words.foldby('word', binop=incr_amount, 
                   initial=0, 
                   combine=add, 
                   combine_initial=0).compute()

print(sorted(am))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-202ce74c6add> in <module>
#      15                    initial=0,
#      16                    combine=add,
# ---> 17                    combine_initial=0).compute()
#      18
#      19 print(sorted(am))
#
# ~/.local/lib/python3.6/site-packages/dask/base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# ~/.local/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
#     435     keys = [x.__dask_keys__() for x in collections]
#     436     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 437     results = schedule(dsk, keys, **kwargs)
#     438     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     439
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2593                     should_rejoin = False
#    2594             try:
# -> 2595                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2596             finally:
#    2597                 for f in futures.values():
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1891                 direct=direct,
#    1892                 local_worker=local_worker,
# -> 1893                 asynchronous=asynchronous,
#    1894             )
#    1895
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     778         else:
#     779             return sync(
# --> 780                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     781             )
#     782
#
# ~/.local/lib/python3.6/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     346     if error[0]:
#     347         typ, exc, tb = error[0]
# --> 348         raise exc.with_traceback(tb)
#     349     else:
#     350         return result[0]
#
# ~/.local/lib/python3.6/site-packages/distributed/utils.py in f()
#     330             if callback_timeout is not None:
#     331                 future = asyncio.wait_for(future, callback_timeout)
# --> 332             result[0] = yield future
#     333         except Exception as exc:
#     334             error[0] = sys.exc_info()
#
# ~/.local/lib/python3.6/site-packages/tornado/gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    1750                             exc = CancelledError(key)
#    1751                         else:
# -> 1752                             raise exception.with_traceback(traceback)
#    1753                         raise exc
#    1754                     if errors == "skip":
#
# ~/.local/lib/python3.6/site-packages/toolz/itertoolz.py in reduceby()
#     621     d = {}
#     622     for item in seq:
# --> 623         k = key(item)
#     624         if k not in d:
#     625             if is_no_default:
#
# TypeError: list indices must be integers or slices, not str

# %%
def to_counter(record):
    return Counter(record)

words_counter= words_ordered.map(to_counter).reduction(Counter.update, sum).compute()
words_counter
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-77ca57997b80> in <module>
#       2     return Counter(record)
#       3
# ----> 4 words_counter= words_ordered.map(to_counter).reduction(Counter.update, sum).compute()
#       5 words_counter
#
# ~/.local/lib/python3.6/site-packages/dask/base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# ~/.local/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
#     435     keys = [x.__dask_keys__() for x in collections]
#     436     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 437     results = schedule(dsk, keys, **kwargs)
#     438     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     439
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2593                     should_rejoin = False
#    2594             try:
# -> 2595                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2596             finally:
#    2597                 for f in futures.values():
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1891                 direct=direct,
#    1892                 local_worker=local_worker,
# -> 1893                 asynchronous=asynchronous,
#    1894             )
#    1895
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     778         else:
#     779             return sync(
# --> 780                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     781             )
#     782
#
# ~/.local/lib/python3.6/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     346     if error[0]:
#     347         typ, exc, tb = error[0]
# --> 348         raise exc.with_traceback(tb)
#     349     else:
#     350         return result[0]
#
# ~/.local/lib/python3.6/site-packages/distributed/utils.py in f()
#     330             if callback_timeout is not None:
#     331                 future = asyncio.wait_for(future, callback_timeout)
# --> 332             result[0] = yield future
#     333         except Exception as exc:
#     334             error[0] = sys.exc_info()
#
# ~/.local/lib/python3.6/site-packages/tornado/gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    1750                             exc = CancelledError(key)
#    1751                         else:
# -> 1752                             raise exception.with_traceback(traceback)
#    1753                         raise exc
#    1754                     if errors == "skip":
#
# ~/.local/lib/python3.6/site-packages/dask/bag/core.py in empty_safe_aggregate()
#    2448 def empty_safe_aggregate(func, parts, is_last):
#    2449     parts2 = (p for p in parts if p is not no_result)
# -> 2450     return empty_safe_apply(func, parts2, is_last)
#    2451
#    2452
#
# ~/.local/lib/python3.6/site-packages/dask/bag/core.py in empty_safe_apply()
#    2439             if not is_last:
#    2440                 return no_result
# -> 2441         return func(part)
#    2442     elif not is_last and len(part) == 0:
#    2443         return no_result
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %%
print(words_counter)
# Out:
# None

# %%
w = words_ordered.take(1)[0]
from collections import Counter

z = dict(Counter(w)+Counter(w))

print(z)
# Out:
# {'PfSWIB': 236, 'var': 118, 'expression': 84, 'P': 82, 'genes': 80, '2': 72, 'gene': 72, '5': 72, '0': 72, 'vars': 66, 'parasite': 64, 'lines': 64, 'falciparum': 58, 'C': 54, 'file': 54, 'Additional': 52, '1': 50, 'stage': 50, 'FKBP': 50, 'parasites': 48, 'LID': 48, 'Fig': 46, 'upsB': 44, '3': 42, 'protein': 42, '3D7': 42, 'HA': 42, 'chromatin': 40, 'upsA': 40, 'line': 40, 'cycle': 38, 'RNA': 36, 'Figure': 36, 'used': 32, 'analysis': 32, 'shield1': 30, '4': 28, 'ring': 28, 'change': 28, 'seq': 28, '6': 26, 'results': 26, 'silencing': 26, 'upsC': 26, 'SWI': 26, 'life': 26, 'performed': 26, 'clone': 26, 'using': 26, 'fusion': 26, 'expressed': 24, 'different': 24, 'process': 24, 'histone': 24, 'specific': 24, 'study': 24, 'partial': 24, 'h': 24, 'PCR': 24, 'BSD': 24, 'subsequently': 24, 'integrated': 24, 'two': 24, '10': 22, 'domain': 22, '05': 22, 'transcription': 22, 'qPCR': 22, 'SWIB': 20, 'SNF': 20, 'proteins': 20, 'could': 20, 'fold': 20, 'involved': 18, 'actin': 18, 'complex': 18, 'well': 18, 'Table': 18, 'terminus': 18, 'tag': 18, 'clones': 18, 'trophozoite': 18, '9': 16, 'nuclear': 16, 'single': 16, '30': 16, 'remodeling': 16, 'also': 16, 'significant': 16, 'vitro': 16, 'transfected': 16, '44': 16, 'drug': 16, 'level': 16, 'screening': 16, 'parasitemia': 16, 'data': 16, 'selected': 16, 'within': 16, 'downregulated': 16, 'Plasmodium': 14, 'family': 14, 'variation': 14, 'one': 14, '11': 14, 'transcriptional': 14, 'sequence': 14, '15': 14, 'regulation': 14, 'factors': 14, 'might': 14, '38': 14, 'growth': 14, '40': 14, 'USA': 14, 'min': 14, 'culture': 14, 'locus': 14, 'pLN': 14, 'obtained': 14, 'absence': 14, '96': 14, 'induced': 14, 'R': 14, 'third': 14, 'malaria': 12, 'including': 12, 'studies': 12, 'play': 12, '24': 12, 'regulating': 12, 'MDM2': 12, 'revealed': 12, 'survival': 12, 'system': 12, 'function': 12, 'mature': 12, 'first': 12, 're': 12, 'integration': 12, 'S1': 12, 'three': 12, 'C2': 12, 'sh': 12, 'compared': 12, 'differentially': 12, 'group': 12, 'log': 12, 'associated': 10, '60': 10, 'major': 10, 'time': 10, '7': 10, '12': 10, '13': 10, 'site': 10, 'multiple': 10, '20': 10, 'key': 10, 'found': 10, 'However': 10, 'binding': 10, 'dependent': 10, 'B': 10, '37': 10, 'related': 10, 'knockdown': 10, '48': 10, 'suggesting': 10, 'role': 10, 'CA': 10, 'synchronized': 10, 'final': 10, 'endogenous': 10, 'primers': 10, 'modified': 10, 'and': 10, '45': 10, 'events': 10, 'respectively': 10, 'previously': 10, 's': 10, 'genome': 10, 'correlation': 10, 'presence': 10, 'exhibited': 10, 'present': 10, 'According': 10, 'knocking': 10, 'upregulated': 10, 'showed': 10, 'linear': 10, 'members': 8, '8': 8, 'active': 8, 'lysine': 8, 'silent': 8, 'heterochromatin': 8, 'according': 8, 'previous': 8, '18': 8, 'controls': 8, 'towards': 8, 'human': 8, 'BAF60b': 8, 'known': 8, 'apoptosis': 8, '35': 8, 'characterized': 8, 'identified': 8, '39': 8, 'especially': 8, 'To': 8, 'addition': 8, 'complexes': 8, 'cultured': 8, 'medium': 8, 'Scientific': 8, 'containing': 8, 'mM': 8, 'II': 8, 'resulting': 8, 'DNA': 8, 'amplification': 8, '95': 8, 'followed': 8, 'cycles': 8, '65': 8, 'initially': 8, 'whereas': 8, 'Bio': 8, 'Rad': 8, 'transfection': 8, 'culturing': 8, 'days': 8, 'stable': 8, 'weeks': 8, 'assay': 8, 'dilution': 8, 'B10': 8, 'described': 8, 'way': 8, 'comparison': 8, 'S2': 8, 'groups': 8, 'PlasmoDB': 8, 'package': 8, 'clustering': 8, 'red': 8, 'may': 8, 'analyzed': 8, 'pattern': 8, 'demonstrated': 8, 'et': 8, 'al': 8, 'virulence': 6, 'antigenic': 6, 'lead': 6, 'modification': 6, 'shown': 6, 'trimethylation': 6, 'particularly': 6, 'usually': 6, 'modifying': 6, 'control': 6, 'putative': 6, '19': 6, 'essential': 6, 'activation': 6, 'roles': 6, '21': 6, 'subtelomeric': 6, 'contrast': 6, 'total': 6, 'SET': 6, '25': 6, 'region': 6, 'periphery': 6, 'variant': 6, 'conserved': 6, 'episomal': 6, 'structure': 6, 'promoter': 6, 'four': 6, 'facilitating': 6, 'ATPase': 6, '32': 6, 'terminal': 6, 'domains': 6, 'alternative': 6, 'form': 6, 'BAF60a': 6, 'ce ...

# %%
print(w.keys())
# Out:
# dict_keys(['PfSWIB', 'var', 'expression', 'P', 'genes', '2', 'gene', '5', '0', 'vars', 'parasite', 'lines', 'falciparum', 'C', 'file', 'Additional', '1', 'stage', 'FKBP', 'parasites', 'LID', 'Fig', 'upsB', '3', 'protein', '3D7', 'HA', 'chromatin', 'upsA', 'line', 'cycle', 'RNA', 'Figure', 'used', 'analysis', 'shield1', '4', 'ring', 'change', 'seq', '6', 'results', 'silencing', 'upsC', 'SWI', 'life', 'performed', 'clone', 'using', 'fusion', 'expressed', 'different', 'process', 'histone', 'specific', 'study', 'partial', 'h', 'PCR', 'BSD', 'subsequently', 'integrated', 'two', '10', 'domain', '05', 'transcription', 'qPCR', 'SWIB', 'SNF', 'proteins', 'could', 'fold', 'involved', 'actin', 'complex', 'well', 'Table', 'terminus', 'tag', 'clones', 'trophozoite', '9', 'nuclear', 'single', '30', 'remodeling', 'also', 'significant', 'vitro', 'transfected', '44', 'drug', 'level', 'screening', 'parasitemia', 'data', 'selected', 'within', 'downregulated', 'Plasmodium', 'family', 'variation', 'one', '11', 'transcriptional', 'sequence', '15', 'regulation', 'factors', 'might', '38', 'growth', '40', 'USA', 'min', 'culture', 'locus', 'pLN', 'obtained', 'absence', '96', 'induced', 'R', 'third', 'malaria', 'including', 'studies', 'play', '24', 'regulating', 'MDM2', 'revealed', 'survival', 'system', 'function', 'mature', 'first', 're', 'integration', 'S1', 'three', 'C2', 'sh', 'compared', 'differentially', 'group', 'log', 'associated', '60', 'major', 'time', '7', '12', '13', 'site', 'multiple', '20', 'key', 'found', 'However', 'binding', 'dependent', 'B', '37', 'related', 'knockdown', '48', 'suggesting', 'role', 'CA', 'synchronized', 'final', 'endogenous', 'primers', 'modified', 'and', '45', 'events', 'respectively', 'previously', 's', 'genome', 'correlation', 'presence', 'exhibited', 'present', 'According', 'knocking', 'upregulated', 'showed', 'linear', 'members', '8', 'active', 'lysine', 'silent', 'heterochromatin', 'according', 'previous', '18', 'controls', 'towards', 'human', 'BAF60b', 'known', 'apoptosis', '35', 'characterized', 'identified', '39', 'especially', 'To', 'addition', 'complexes', 'cultured', 'medium', 'Scientific', 'containing', 'mM', 'II', 'resulting', 'DNA', 'amplification', '95', 'followed', 'cycles', '65', 'initially', 'whereas', 'Bio', 'Rad', 'transfection', 'culturing', 'days', 'stable', 'weeks', 'assay', 'dilution', 'B10', 'described', 'way', 'comparison', 'S2', 'groups', 'PlasmoDB', 'package', 'clustering', 'red', 'may', 'analyzed', 'pattern', 'demonstrated', 'et', 'al', 'virulence', 'antigenic', 'lead', 'modification', 'shown', 'trimethylation', 'particularly', 'usually', 'modifying', 'control', 'putative', '19', 'essential', 'activation', 'roles', '21', 'subtelomeric', 'contrast', 'total', 'SET', '25', 'region', 'periphery', 'variant', 'conserved', 'episomal', 'structure', 'promoter', 'four', 'facilitating', 'ATPase', '32', 'terminal', 'domains', 'alternative', 'form', 'BAF60a', 'cell', '36', 'regulator', 'removal', 'crucial', 'unknown', 'functional', 'downregulation', 'certain', 'clonal', 'follows', 'Invitrogen', 'Thermo', 'Fisher', 'Carlsbad', 'Shanghai', 'China', 'ml', 'type', 'sorbitol', 'subjected', 'treatment', 'high', 'detect', 'reaction', '50', 'listed', 'kb', 'degron', 'fused', 'plasmid', 'resistance', 'applied', 'subsequent', 'cycling', 'therefore', 'order', 'plates', 'screened', 'testing', '54', 'western', '01', 'diluted', 'test', 'curve', 'reference', 'based', 'edgeR', 'FDR', 'low', 'degradation', 'shows', 'samples', 'GCA', '2b', 'difference', 'The', 'profiling', 'Among', 'hierarchical', 'significantly', 'patterns', 'S4', 'variants', 'S5', 'except', 'T', 'p53', 'discovered', 'PfRNase', 'removes', 'surface', 'causes', 'PfEMP1', 'encoded', 'comprising', 'approximately', 'factor', 'mutually', 'exclusive', 'immune', 'evasion', 'mediated', 'epigenetic', 'mechanisms', 'architecture', 'It', 'enriched', 'modifications', 'acetylation', 'H3K9ac', 'start', '14', 'marker', 'UTR', 'enzymes', 'PfMYST', 'PfGCN5', 'important' ...

# %%
words_ordered.groupby(lambda item: item.keys()).starmap(lambda k, v: (k, len(v))).compute()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-596f7bc8a555> in <module>
# ----> 1 words_ordered.groupby(lambda item: item.keys()).starmap(lambda k, v: (k, len(v))).compute()
#
# ~/.local/lib/python3.6/site-packages/dask/base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# ~/.local/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
#     435     keys = [x.__dask_keys__() for x in collections]
#     436     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 437     results = schedule(dsk, keys, **kwargs)
#     438     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     439
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2593                     should_rejoin = False
#    2594             try:
# -> 2595                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2596             finally:
#    2597                 for f in futures.values():
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1891                 direct=direct,
#    1892                 local_worker=local_worker,
# -> 1893                 asynchronous=asynchronous,
#    1894             )
#    1895
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     778         else:
#     779             return sync(
# --> 780                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     781             )
#     782
#
# ~/.local/lib/python3.6/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     346     if error[0]:
#     347         typ, exc, tb = error[0]
# --> 348         raise exc.with_traceback(tb)
#     349     else:
#     350         return result[0]
#
# ~/.local/lib/python3.6/site-packages/distributed/utils.py in f()
#     330             if callback_timeout is not None:
#     331                 future = asyncio.wait_for(future, callback_timeout)
# --> 332             result[0] = yield future
#     333         except Exception as exc:
#     334             error[0] = sys.exc_info()
#
# ~/.local/lib/python3.6/site-packages/tornado/gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# ~/.local/lib/python3.6/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    1750                             exc = CancelledError(key)
#    1751                         else:
# -> 1752                             raise exception.with_traceback(traceback)
#    1753                         raise exc
#    1754                     if errors == "skip":
#
# ~/.local/lib/python3.6/site-packages/toolz/itertoolz.py in groupby()
#      98         key = getter(key)
#      99     d = collections.defaultdict(lambda: [].append)
# --> 100     for item in seq:
#     101         d[key(item)](item)
#     102     rv = {}
#
# ~/.local/lib/python3.6/site-packages/dask/bag/core.py in __next__()
#    2020             kwargs = dict(zip(self.kwarg_keys, vals[-self.nkws :]))
#    2021             return self.f(*args, **kwargs)
# -> 2022         return self.f(*vals)
#    2023
#    2024     def check_all_iterators_consumed(self):
#
# ~/.local/lib/python3.6/site-packages/dask/bag/chunk.py in groupby_tasks_group_hash()
#      15
#      16 def groupby_tasks_group_hash(x, hash, grouper):
# ---> 17     return hash(grouper(x)), x
#      18
#      19
#
# TypeError: unhashable type: 'dict_keys'

# %%
word= words.take(1)[0]
words_sorted = {k: v for k, v in sorted(word.items(), key=lambda item: item[1], reverse=True)}
words_sorted
# Out:
# {'PfSWIB': 118,
#  'var': 59,
#  'expression': 42,
#  'P': 41,
#  'genes': 40,
#  '2': 36,
#  'gene': 36,
#  '5': 36,
#  'The': 36,
#  '0': 36,
#  'vars': 33,
#  'parasite': 32,
#  'lines': 32,
#  'falciparum': 29,
#  'C': 27,
#  'file': 27,
#  'Additional': 26,
#  '1': 25,
#  'stage': 25,
#  'FKBP': 25,
#  'parasites': 24,
#  'LID': 24,
#  'Fig': 23,
#  'In': 22,
#  'upsB': 22,
#  '3': 21,
#  'protein': 21,
#  '3D7': 21,
#  'HA': 21,
#  'chromatin': 20,
#  'upsA': 20,
#  'line': 20,
#  'cycle': 19,
#  'RNA': 18,
#  'Figure': 18,
#  'used': 16,
#  'analysis': 16,
#  'shield1': 15,
#  '4': 14,
#  'ring': 14,
#  'change': 14,
#  'seq': 14,
#  '6': 13,
#  'results': 13,
#  'silencing': 13,
#  'upsC': 13,
#  'SWI': 13,
#  'life': 13,
#  'performed': 13,
#  'clone': 13,
#  'using': 13,
#  'fusion': 13,
#  'expressed': 12,
#  'different': 12,
#  'process': 12,
#  'histone': 12,
#  'specific': 12,
#  'study': 12,
#  'partial': 12,
#  'h': 12,
#  'PCR': 12,
#  'BSD': 12,
#  'subsequently': 12,
#  'integrated': 12,
#  'two': 12,
#  '10': 11,
#  'domain': 11,
#  '05': 11,
#  'transcription': 11,
#  'qPCR': 11,
#  'SWIB': 10,
#  'SNF': 10,
#  'proteins': 10,
#  'could': 10,
#  'fold': 10,
#  'involved': 9,
#  'actin': 9,
#  'complex': 9,
#  'well': 9,
#  'Table': 9,
#  'terminus': 9,
#  'tag': 9,
#  'clones': 9,
#  'trophozoite': 9,
#  '9': 8,
#  'nuclear': 8,
#  'single': 8,
#  '30': 8,
#  'remodeling': 8,
#  'also': 8,
#  'significant': 8,
#  'vitro': 8,
#  'transfected': 8,
#  '44': 8,
#  'drug': 8,
#  'level': 8,
#  'screening': 8,
#  'parasitemia': 8,
#  'data': 8,
#  'selected': 8,
#  'within': 8,
#  'downregulated': 8,
#  'Plasmodium': 7,
#  'family': 7,
#  'variation': 7,
#  'one': 7,
#  '11': 7,
#  'transcriptional': 7,
#  'sequence': 7,
#  '15': 7,
#  'regulation': 7,
#  'factors': 7,
#  'might': 7,
#  '38': 7,
#  'growth': 7,
#  '40': 7,
#  'USA': 7,
#  'min': 7,
#  'culture': 7,
#  'locus': 7,
#  'pLN': 7,
#  'obtained': 7,
#  'absence': 7,
#  '96': 7,
#  'induced': 7,
#  'R': 7,
#  'third': 7,
#  'malaria': 6,
#  'including': 6,
#  'studies': 6,
#  'play': 6,
#  '24': 6,
#  'regulating': 6,
#  'MDM2': 6,
#  'revealed': 6,
#  'survival': 6,
#  'To': 6,
#  'system': 6,
#  'function': 6,
#  'mature': 6,
#  'first': 6,
#  're': 6,
#  'integration': 6,
#  'S1': 6,
#  'three': 6,
#  'A': 6,
#  'C2': 6,
#  'sh': 6,
#  'compared': 6,
#  'differentially': 6,
#  'group': 6,
#  'log': 6,
#  'associated': 5,
#  '60': 5,
#  'major': 5,
#  'time': 5,
#  '7': 5,
#  '12': 5,
#  '13': 5,
#  'site': 5,
#  'multiple': 5,
#  '20': 5,
#  'key': 5,
#  'found': 5,
#  'However': 5,
#  'binding': 5,
#  'dependent': 5,
#  'B': 5,
#  '37': 5,
#  'related': 5,
#  'knockdown': 5,
#  '48': 5,
#  'suggesting': 5,
#  'role': 5,
#  'CA': 5,
#  'synchronized': 5,
#  'final': 5,
#  'endogenous': 5,
#  'primers': 5,
#  'modified': 5,
#  'and': 5,
#  '45': 5,
#  'events': 5,
#  'respectively': 5,
#  'previously': 5,
#  's': 5,
#  'genome': 5,
#  'correlation': 5,
#  'presence': 5,
#  'exhibited': 5,
#  'present': 5,
#  'According': 5,
#  'knocking': 5,
#  'upregulated': 5,
#  'showed': 5,
#  'linear': 5,
#  'members': 4,
#  'It': 4,
#  'For': 4,
#  '8': 4,
#  'This': 4,
#  'active': 4,
#  'lysine': 4,
#  'silent': 4,
#  'heterochromatin': 4,
#  'according': 4,
#  'previous': 4,
#  '18': 4,
#  'controls': 4,
#  'towards': 4,
#  'human': 4,
#  'BAF60b': 4,
#  'known': 4,
#  'apoptosis': 4,
#  '35': 4,
#  'characterized': 4,
#  'identified': 4,
#  '39': 4,
#  'especially': 4,
#  'We': 4,
#  'addition': 4,
#  'complexes': 4,
#  'cultured': 4,
#  'medium': 4,
#  'Scientific': 4,
#  'containing': 4,
#  'mM': 4,
#  'II': 4,
#  'resulting': 4,
#  'DNA': 4,
#  'amplification': 4,
#  '95': 4,
#  'followed': 4,
#  'cycles': 4,
#  '65': 4,
#  'initially': 4,
#  'whereas': 4,
#  'Bio': 4,
#  'Rad': 4,
#  'transfection': 4,
#  'culturing': 4,
#  'days': 4,
#  'stable': 4,
#  'weeks': 4,
#  'assay': 4,
#  'dilution': 4,
#  'B10': 4,
#  'described': 4,
#  'way': 4,
#  'comparison': 4,
#  'S2': 4,
#  'groups': 4,
#  'PlasmoDB': 4,
#  'package': 4,
#  'clustering': 4,
#  'red': 4,
#  'may': 4,
#  'analyzed': 4,
#  'pattern': 4,
#  'demonstrated': 4,
#  'et': 4,
#  'al': 4,
#  'virulence': 3,
#  'antigenic': 3,
#  'lead': 3,
#  'modification': 3,
#  'shown': 3,
#  'trimethylation': 3,
#  'particularly': 3,
#  'usually': 3,
#  'modifying': 3,
#  'control': 3,
#  'putative': 3,
#  '19': 3,
#  'essential': 3,
#  'activation': 3,
#  'roles': 3,
#  '21': 3,
#  'subtelomeric': 3,
#  'contrast': 3,
#  'total': 3,
#  'SET': 3,
#  '25': 3,
#  'region': 3,
#  'periphery': 3,
#  'variant': 3,
#  'conserved': 3,
#  'episomal': 3,
#  'structure': 3,
#  'promoter': 3,
#  'four': 3,
#  'facilitating': 3,
#  'ATPase': 3,
#  '32': 3,
#  'terminal': 3,
#  'domains': 3,
#  'alternative': 3,
#  'form': 3,
#  'BAF60a': 3,
#  'cell': 3,
#  '36': 3,
#  'regulator': 3,
#  'removal': 3,
#  'crucial': 3,
#  'unknown': 3,
#  'functional': 3,
#  'downregulation': 3,
#  'certain': 3,
#  'clonal': 3,
#  'follows': 3,
#  'Invitrogen': 3,
#  'Thermo': 3,
#  'Fisher': 3,
#  'Carlsbad': 3,
#  'Shanghai': 3,
#  'China': 3,
#  'ml': 3,
#  'type': 3,
#  'sorbitol': 3,
#  'subjected': 3,
#  'treatment': 3,
#  'high': 3,
#  'detect': 3,
#  'reaction': 3,
#  '50': 3,
#  'listed': 3,
#  'kb': 3,
#  'degron': 3,
#  'fused': 3,
#  'plasmid': 3,
#  'resistance': 3,
#  'applied': 3,
#  'subsequent': 3,
#  'cycling': 3,
#  'therefore': 3,
#  'order': 3,
#  'plates': 3,
#  'screened': 3,
#  'testing': 3,
#  '54': 3,
#  'western': 3,
#  '01': 3,
#  'diluted': 3,
#  'test': 3,
#  'curve': 3,
#  'reference': 3,
#  'based': 3,
#  'edgeR': 3,
#  'FDR': 3,
#  'low': 3,
#  'degradation': 3,
#  'shows': 3,
#  'samples': 3,
#  'GCA': 3,
#  '2b': 3,
#  'difference': 3,
#  'profiling': 3,
#  'Among': 3,
#  'hierarchical': 3,
#  'significantly': 3,
#  'patterns': 3,
#  'S4': 3,
#  'variants': 3,
#  'S5': 3,
#  'except': 3,
#  'T': 3,
#  'p53': 3,
#  'discovered': 3,
#  'PfRNase': 3,
#  'removes': 3,
#  'surface': 3,
#  'PfEMP1': 2,
#  'encoded': 2,
#  'comprising': 2,
#  'approximately': 2,
#  'factor': 2,
#  'mutually': 2,
#  'exclusive': 2,
#  'immune': 2,
#  'evasion': 2,
#  'mediated': 2,
#  'epigenetic': 2,
#  'mechanisms': 2,
#  'architecture': 2,
#  'enriched': 2,
#  'modifications': 2,
#  'acetylation': 2,
#  'H3K9ac': 2,
#  'start': 2,
#  '14': 2,
#  'marker': 2,
#  'UTR': 2,
#  'enzymes': 2,
#  'PfMYST': 2,
#  'PfGCN5': 2,
#  'important': 2,
#  'yeast': 2,
#  'Two': 2,
#  '22': 2,
#  'subtype': 2,
#  'PfSir2B': 2,
#  'silences': 2,
#  'Furthermore': 2,
#  'PfSET10': 2,
#  '26': 2,
#  'H3K36me3': 2,
#  '27': 2,
#  '28': 2,
#  'ApiAP2': 2,
#  'member': 2,
#  'binds': 2,
#  '29': 2,
#  'On': 2,
#  'hand': 2,
#  'various': 2,
#  'trans': 2,
#  'activity': 2,
#  'another': 2,
#  'induces': 2,
#  'ATP': 2,
#  'temporal': 2,
#  'All': 2,
#  'remodeler': 2,
#  'consist': 2,
#  'SWI2': 2,
#  'includes': 2,
#  'HSA': 2,
#  'SANT': 2,
#  'post': 2,
#  'carry': 2,
#  'generally': 2,
#  'Complex': 2,
#  '34': 2,
#  'responsible': 2,
#  'halting': 2,
#  'tune': 2,
#  'balance': 2,
#  'repair': 2,
#  'induction': 2,
#  'matrix': 2,
#  'GenBank': 2,
#  'PCD': 2,
#  'transient': 2,
#  'localization': 2,
#  'Further': 2,
#  'profound': 2,
#  'effects': 2,
#  'interacting': 2,
#  'remains': 2,
#  'unclear': 2,
#  'whether': 2,
#  'molecular': 2,
#  'mechanism': 2,
#  'new': 2,
#  'conditional': 2,
#  'dysfunction': 2,
#  'aberrant': 2,
#  'better': 2,
#  'understanding': 2,
#  'regulatory': 2,
#  'CRCs': 2,
#  'contributing': 2,
#  'pathogenesis': 2,
#  'thawed': 2,
#  'continuous': 2,
#  'cultivation': 2,
#  'standard': 2,
#  'Sigma': 2,
#  'Aldrich': 2,
#  'O': 2,
#  'N': 2,
#  'obtain': 2,
#  'tightly': 2,
#  'percoll': 2,
#  'method': 2,
#  'brief': 2,
#  'rings': 2,
#  'repeated': 2,
#  'twice': 2,
#  'suspended': 2,
#  'RBC': 2,
#  'conditions': 2,
#  '62': 2,
#  'extension': 2,
#  'ENR': 2,
#  'GFP': 2,
#  'ApaI': 2,
#  'multicloning': 2,
#  'construct': 2,
#  'ligated': 2,
#  'via': 2,
#  'tandem': 2,
#  'repeat': 2,
#  'sequences': 2,
#  'influenza': 2,
#  'hemagglutinin': 2,
#  'comprised': 2,
#  'rapamycin': 2,
#  'amino': 2,
#  'acid': 2,
#  '1a': 2,
#  'BioRad': 2,
#  'Laboratories': 2,
#  'Hercules': 2,
#  '94547': 2,
#  'minimum': 2,
#  '100': 2,
#  'purified': 2,
#  'less': 2,
#  'selection': 2,
#  'concentration': 2,
#  'bsd': 2,
#  'would': 2,
#  'crossover': 2,
#  'Therefore': 2,
#  'introduced': 2,
#  'enrich': 2,
#  '1b': 2,
#  'primer': 2,
#  'serial': 2,
#  'transfections': 2,
#  'detected': 2,
#  '94': 2,
#  'analyze': 2,
#  'prepared': 2,
#  'SDS': 2,
#  'blot': 2,
#  'An': 2,
#  '1000': 2,
#  'identify': 2,
#  'blotting': 2,
#  'implemented': 2,
#  'significance': 2,
#  'determined': 2,
#  'invasion': 2,
#  'collected': 2,
#  'divided': 2,
#  'wells': 2,
#  'μM': 2,
#  'subject': 2,
#  'ANOVA': 2,
#  'individual': 2,
#  'assays': 2,
#  'experimental': 2,
#  'statistical': 2,
#  'duplicate': 2,
#  'http': 2,
#  'plasm': 2,
#  'odb': 2,
#  'org': 2,
#  'fasta': 2,
#  'v0': 2,
#  'quality': 2,
#  'reads': 2,
#  'profiles': 2,
#  'differential': 2,
#  'feature': 2,
#  'Blasticidin': 2,
#  'S': 2,
#  'Day': 2,
#  'detecting': 2,
#  'proficiency': 2,
#  'full': 2,
#  'length': 2,
#  'recombinant': 2,
#  'caused': 2,
#  'Western': 2,
#  'small': 2,
#  'molecule': 2,
#  'Alternatively': 2,
#  'As': 2,
#  '2a': 2,
#  'successfully': 2,
#  'stages': 2,
#  '890': 2,
#  '0394': 2,
#  '006': 2,
#  '4205': 2,
#  'FC': 2,
#  'depth': 2,
#  'FPKM': 2,
#  'values': 2,
#  'characteristics': 2,
#  'proved': 2,
#  'These': 2,
#  'among': 2,
#  'corresponds': 2,
#  'vs': 2,
#  'asterisk': 2,
#  'black': 2,
#  'cluster': 2,
#  'covered': 2,
#  'regression': 2,
#  'S6': 2,
#  'r': 2,
#  '6281': 2,
#  '0001': 2,
#  'arrow': 2,
#  'PF3D7_1240300': 2,
#  'highly': 2,
#  'drastically': 2,
#  'PF3D7_1219300': 2,
#  'hour': 2,
#  'S7': 2,
#  'ratio': 2,
#  'activated': 2,
#  'least': 2,
#  'PfCRCs': 2,
#  'mammalian': 2,
#  'BAFs': 2,
#  'activities': 2,
#  'participate': 2,
#  'interactions': 2,
#  'Similarly': 2,
#  'encodes': 2,
#  'developed': 2,
#  'confirmed': 2,
#  'either': 2,
#  'due': 2,
#  'takes': 2,
#  'heat': 2,
#  'stress': 2,
#  'They': 2,
#  'PfARK3': 2,
#  'H3': 2,
#  'phosphorylation': 2,
#  'observed': 2,
#  'leads': 2,
#  'Depletion': 2,
#  'methods': 2,
#  'host': 2,
#  'malignant': 1,
#  'cerebral': 1,
#  'CM': 1,
#  'pregnancy': 1,
#  'PAM': 1,
#  'cause': 1,
#  'death': 1,
#  '435': 1,
#  '000': 1,
#  'individuals': 1,
#  'annually': 1,
#  'erythrocyte': 1,
#  'membrane': 1,
#  'clinical': 1,
#  'pathogenicity': 1,
#  'remarkable': 1,
#  'remaining': 1,
#  'silenced': 1,
#  'generation': 1,
#  'able': 1,
#  'express': 1,
#  'switches': 1,
#  'chronic': 1,
#  'infection': 1,
#  'proven': 1,
#  'relocation': 1,
#  'euchromatic': 1,
#  'H3K4me3': 1,
#  'near': 1,
#  'TSS': 1,
#  'lysine9': 1,
#  'H3K9me3': 1,
#  'coding': 1,
#  '16': 1,
#  '17': 1,
#  'PfSIR2': 1,
#  'PfSET': 1,
#  'considered': 1,
#  'reversible': 1,
#  'acetyltransferases': 1,
#  'HATs': 1,
#  'capable': 1,
#  'acetylating': 1,
#  'lysines': 1,
#  'H4': 1,
#  'orthologue': 1,
#  'HAT': 1,
#  'influences': 1,
#  'H3K9': 1,
#  'K14': 1,
#  'marks': 1,
#  'paralogues': 1,
#  'class': 1,
#  'III': 1,
#  'HDAC': 1,
#  'deacetylases': 1,
#  'Sir2': 1,
#  'maintaining': 1,
#  'PfSir2A': 1,
#  'deacetylates': 1,
#  'H3K14ac': 1,
#  'H4K16ac': 1,
#  '23': 1,
#  'upsEand': 1,
#  'ten': 1,
#  'methyltransferases': 1,
#  'HKMTs': 1,
#  'belonging': 1,
#  'localizes': 1,
#  'specialized': 1,
#  'H3K4me4': 1,
#  'transferase': 1,
#  'PfSETvs': 1,
#  'Moreover': 1,
#  'subnuclear': 1,
#  'contributes': 1,
#  'default': 1,
#  'since': 1,
#  'located': 1,
#  'promoters': 1,
#  'seem': 1,
#  'occupy': 1,
#  'privileged': 1,
#  'making': 1,
#  'permissive': 1,
#  'transcribe': 1,
#  'PF11_0091': 1,
#  'motif': 1,
#  'introns': 1,
#  'mediates': 1,
#  'anchoring': 1,
#  'recruiting': 1,
#  'polymerized': 1,
#  'de': 1,
#  'represses': 1,
#  'intimately': 1,
#  'PfAlbas': 1,
#  'contribute': 1,
#  'PfSIP2': 1,
#  'recruitment': 1,
#  'organization': 1,
#  'SPE2': 1,
#  '31': 1,
#  'comprehensive': 1,
#  'Particularly': 1,
#  'classes': 1,
#  'remodelers': 1,
#  'spatial': 1,
#  'families': 1,
#  'SNF2family': 1,
#  'subunit': 1,
#  'featuring': 1,
#  '33': 1,
#  'helicase': 1,
#  'bromodomain': 1,
#  'Some': 1,
#  'subunits': 1,
#  'extra': 1,
#  'hBAF155': 1,
#  '170': 1,
#  'SWIRM': 1,
#  'hBAF60': 1,
#  'polybromo': 1,
#  'bromodomains': 1,
#  'ability': 1,
#  'Recently': 1,
#  'PF3D7_0611400': 1,
#  'trigger': 1,
#  'properties': 1,
#  'address': 1,
#  'propose': 1,
#  'reversion': 1,
#  'affect': 1,
#  'development': 1,
#  'provides': 1,
#  'insight': 1,
#  'established': 1,
#  'procedures': 1,
#  '41': 1,
#  'isolates': 1,
#  'RPMI': 1,
#  '1640': 1,
#  'Hepes': 1,
#  'l': 1,
#  'glutamine': 1,
#  'hypoxanthine': 1,
#  'mg': 1,
#  'gentamicin': 1,
#  'Albumax': 1,
#  'serum': 1,
#  'AB': 1,
#  'Changhai': 1,
#  'Hospital': 1,
#  'Second': 1,
#  'Military': 1,
#  'Medical': 1,
#  'University': 1,
#  'Cultures': 1,
#  'grown': 1,
#  'media': 1,
#  'erythrocytes': 1,
#  'hematocrit': 1,
#  'CO': 1,
#  '92': 1,
#  'synchronization': 1,
#  '42': 1,
#  '43': 1,
#  'schizonts': 1,
#  'isolated': 1,
#  'cushion': 1,
#  'allowed': 1,
#  'invade': 1,
#  'fresh': 1,
#  'RBCs': 1,
#  'washed': 1,
#  'complete': 1,
#  'originated': 1,
#  'extraction': 1,
#  'QIAamp': 1,
#  'Mini': 1,
#  'Kit': 1,
#  'Qiagen': 1,
#  'Hilden': 1,
#  'Germany': 1,
#  'fidelity': 1,
#  'KOD': 1,
#  'plus': 1,
#  'Neo': 1,
#  'enzyme': 1,
#  'Toyobo': 1,
#  'Osaka': 1,
#  'Japan': 1,
#  'DQ813653': 1,
#  'deleting': 1,
#  'whole': 1,
#  'pfenr': 1,
#  'gfp': 1,
#  'cassette': 1,
#  'fragments': 1,
#  'BamHI': 1,
#  '6900': 1,
#  'bp': 1,
#  'calmodulin': 1,
#  'CaM': 1,
#  'fragment': 1,
#  'substituted': 1,
#  'ASCI': 1,
#  'Three': 1,
#  'duplicates': 1,
#  'YPYDVPDYA': 1,
#  'linker': 1,
#  'AAAAVDAAAA': 1,
#  'vector': 1,
#  'transfect': 1,
#  'consists': 1,
#  'FK506': 1,
#  'Transfections': 1,
#  'ringstage': 1,
#  'mm': 1,
#  'Gene': 1,
#  'Pulser': 1,
#  'cuvettes': 1,
#  'μg': 1,
#  'recombinated': 1,
#  'electroporation': 1,
#  'GenePulse': 1,
#  'Xcell': 1,
#  'electroporator': 1,
#  '310': 1,
#  'V': 1,
#  '950': 1,
#  'μF': 1,
#  'ms': 1,
#  'Positive': 1,
#  'nM': 1,
#  'maintained': 1,
#  'Those': 1,
#  'adopted': 1,
#  'carrying': 1,
#  'offer': 1,
#  'select': 1,
#  'initial': 1,
#  'mixture': 1,
#  'mode': 1,
#  'original': 1,
#  'µg': 1,
#  'possibly': 1,
#  'sorted': 1,
#  'rounds': 1,
#  'After': 1,
#  'Primers': 1,
#  'P2': 1,
#  'P4': 1,
#  'P5': 1,
#  'upstream': 1,
#  'downstream': 1,
#  'Fn': 1,
#  'forward': 1,
#  'utilized': 1,
#  'detailed': 1,
#  '46': 1,
#  'extended': 1,
#  'see': 1,
#  'extracts': 1,
#  'saponin': 1,
#  'loading': 1,
#  'buffer': 1,
#  'separated': 1,
#  'PAGE': 1,
#  'gel': 1,
#  'Total': 1,
#  'antibody': 1,
#  'aldolase': 1,
#  'Roche': 1,
#  'Indianapolis': 1,
#  'positive': 1,
#  'Rabbit': 1,
#  'anti': 1,
#  'Abcam': 1,
#  'Cambridge': 1,
#  'UK': 1,
#  'enhanced': 1,
#  'chemiluminescence': 1,
#  'ECL': 1,
#  'kit': 1,
#  'GE': 1,
#  'Healthcare': 1,
#  'Uppsala': 1,
#  'Sweden': 1,
#  'develop': 1,
#  'blots': 1,
#  'theoretical': 1,
#  'weight': 1,
#  '92kD': 1,
#  '5kD': 1,
#  '22kD': 1,
#  'graylevel': 1,
#  'image': 1,
#  'procedure': 1,
#  'ImageJ': 1,
#  'software': 1,
#  'Statistical': 1,
#  'Synchronized': 1,
#  'Each': 1,
#  'cultures': 1,
#  'plate': 1,
#  'µl': 1,
#  'pellets': 1,
#  'Shield1': 1,
#  'ethanol': 1,
#  'Clontech': 1,
#  'Mountain': 1,
#  'View': 1,
#  'added': 1,
#  'Consequently': 1,
#  'PfSWIBΔ': 1,
#  'counted': 1,
#  'every': 1,
#  'rate': 1,
#  'statistically': 1,
#  'Bonferroni': 1,
#  'Growth': 1,
#  'triplicate': 1,
#  'pairs': 1,
#  'published': 1,
#  'elsewhere': 1,
#  '47': 1,
#  'synchronous': 1,
#  'extracted': 1,
#  'TRIzol': 1,
#  'reagent': 1,
#  'cDNA': 1,
#  'accordance': 1,
#  'manufacturer': 1,
#  'recommendations': 1,
#  'Thermofisher': 1,
#  'calculated': 1,
#  'ΔΔCq': 1,
#  'QuantStudio': 1,
#  'Flex': 1,
#  'Real': 1,
#  'Time': 1,
#  'System': 1,
#  'Applied': 1,
#  'Biosystems': 1,
#  'Singapore': 1,
#  'program': 1,
#  'Seryl': 1,
#  'tRNA': 1,
#  'synthetase': 1,
#  'normalize': 1,
#  'tailed': 1,
#  'Student': 1,
#  't': 1,
#  'screen': 1,
#  'carried': 1,
#  'transcript': 1,
#  'information': 1,
#  'aligner': 1,
#  'STAR': 1,
#  'v2': 1,
#  '3a': 1,
#  '49': 1,
#  'create': 1,
#  'catalog': 1,
#  'files': 1,
#  'GFF3': 1,
#  'annotation': 1,
#  '34_Pfalcipa': 1,
#  ...}

# %%
words.take(1)
# Out:
# ({'Plasmodium': 7,
#   'falciparum': 29,
#   'malignant': 1,
#   'malaria': 6,
#   'cerebral': 1,
#   'CM': 1,
#   'pregnancy': 1,
#   'associated': 5,
#   'PAM': 1,
#   '1': 25,
#   '2': 36,
#   'cause': 1,
#   'death': 1,
#   '435': 1,
#   '000': 1,
#   'individuals': 1,
#   'annually': 1,
#   '3': 21,
#   'erythrocyte': 1,
#   'membrane': 1,
#   'protein': 21,
#   'PfEMP1': 2,
#   'encoded': 2,
#   'var': 59,
#   'gene': 36,
#   'family': 7,
#   'comprising': 2,
#   'approximately': 2,
#   '60': 5,
#   'members': 4,
#   'major': 5,
#   'virulence': 3,
#   'factor': 2,
#   'involved': 9,
#   'antigenic': 3,
#   'variation': 7,
#   'clinical': 1,
#   'pathogenicity': 1,
#   '4': 14,
#   '5': 36,
#   'It': 4,
#   'remarkable': 1,
#   'expression': 42,
#   'mutually': 2,
#   'exclusive': 2,
#   'For': 4,
#   'parasite': 32,
#   'time': 5,
#   'one': 7,
#   'genes': 40,
#   'expressed': 12,
#   'remaining': 1,
#   'silenced': 1,
#   '6': 13,
#   '7': 5,
#   'In': 22,
#   'generation': 1,
#   'P': 41,
#   'able': 1,
#   'express': 1,
#   'different': 12,
#   'switches': 1,
#   'lead': 3,
#   'results': 13,
#   'immune': 2,
#   'evasion': 2,
#   'chronic': 1,
#   'infection': 1,
#   '8': 4,
#   '9': 8,
#   '10': 11,
#   '11': 7,
#   'This': 4,
#   'process': 12,
#   'proven': 1,
#   'mediated': 2,
#   'epigenetic': 2,
#   'mechanisms': 2,
#   'including': 6,
#   'chromatin': 20,
#   'modification': 3,
#   'nuclear': 8,
#   'architecture': 2,
#   'relocation': 1,
#   '12': 5,
#   '13': 5,
#   'shown': 3,
#   'single': 8,
#   'active': 4,
#   'enriched': 2,
#   'euchromatic': 1,
#   'modifications': 2,
#   'histone': 12,
#   'lysine': 4,
#   'acetylation': 2,
#   'H3K9ac': 2,
#   'trimethylation': 3,
#   'H3K4me3': 1,
#   'particularly': 3,
#   'near': 1,
#   'transcriptional': 7,
#   'start': 2,
#   'site': 5,
#   'TSS': 1,
#   '14': 2,
#   'silent': 4,
#   'usually': 3,
#   'heterochromatin': 4,
#   'marker': 2,
#   'lysine9': 1,
#   'H3K9me3': 1,
#   'UTR': 2,
#   'coding': 1,
#   'sequence': 7,
#   '15': 7,
#   '16': 1,
#   '17': 1,
#   'modifying': 3,
#   'enzymes': 2,
#   'PfMYST': 2,
#   'PfGCN5': 2,
#   'PfSIR2': 1,
#   'PfSET': 1,
#   'considered': 1,
#   'important': 2,
#   'control': 3,
#   'reversible': 1,
#   'according': 4,
#   'previous': 4,
#   'studies': 6,
#   'putative': 3,
#   'acetyltransferases': 1,
#   'HATs': 1,
#   'capable': 1,
#   'acetylating': 1,
#   'multiple': 5,
#   'lysines': 1,
#   'H4': 1,
#   '18': 4,
#   '19': 3,
#   'orthologue': 1,
#   'yeast': 2,
#   'HAT': 1,
#   'influences': 1,
#   'H3K9': 1,
#   'K14': 1,
#   'essential': 3,
#   'marks': 1,
#   'activation': 3,
#   '20': 5,
#   'Two': 2,
#   'paralogues': 1,
#   'class': 1,
#   'III': 1,
#   'HDAC': 1,
#   'deacetylases': 1,
#   'Sir2': 1,
#   'play': 6,
#   'key': 5,
#   'roles': 3,
#   'maintaining': 1,
#   '21': 3,
#   '22': 2,
#   'PfSir2A': 1,
#   'deacetylates': 1,
#   'H3K14ac': 1,
#   'H4K16ac': 1,
#   '23': 1,
#   'silencing': 13,
#   'subtelomeric': 3,
#   'upsA': 20,
#   'upsEand': 1,
#   'upsC': 13,
#   'subtype': 2,
#   'vars': 33,
#   'contrast': 3,
#   'PfSir2B': 2,
#   'silences': 2,
#   'upsB': 22,
#   'Furthermore': 2,
#   'total': 3,
#   'ten': 1,
#   'methyltransferases': 1,
#   'HKMTs': 1,
#   'belonging': 1,
#   'SET': 3,
#   'domain': 11,
#   'found': 5,
#   '24': 6,
#   '25': 3,
#   'PfSET10': 2,
#   'localizes': 1,
#   'specialized': 1,
#   'region': 3,
#   'periphery': 3,
#   'H3K4me4': 1,
#   'transferase': 1,
#   '26': 2,
#   'variant': 3,
#   'PfSETvs': 1,
#   'controls': 4,
#   'H3K36me3': 2,
#   '27': 2,
#   'Moreover': 1,
#   'subnuclear': 1,
#   'contributes': 1,
#   'regulation': 7,
#   'default': 1,
#   'since': 1,
#   'located': 1,
#   '28': 2,
#   'However': 5,
#   'promoters': 1,
#   'seem': 1,
#   'occupy': 1,
#   'privileged': 1,
#   'making': 1,
#   'permissive': 1,
#   'transcribe': 1,
#   'PF11_0091': 1,
#   'ApiAP2': 2,
#   'member': 2,
#   'binds': 2,
#   'conserved': 3,
#   'motif': 1,
#   'introns': 1,
#   'mediates': 1,
#   'episomal': 3,
#   'anchoring': 1,
#   'towards': 4,
#   'recruiting': 1,
#   'actin': 9,
#   'complex': 9,
#   'polymerized': 1,
#   'de': 1,
#   'represses': 1,
#   '29': 2,
#   'On': 2,
#   'hand': 2,
#   'various': 2,
#   'trans': 2,
#   'factors': 7,
#   'intimately': 1,
#   'regulating': 6,
#   'structure': 3,
#   'activity': 2,
#   'PfAlbas': 1,
#   'contribute': 1,
#   '30': 8,
#   'PfSIP2': 1,
#   'another': 2,
#   'recruitment': 1,
#   'organization': 1,
#   'binding': 5,
#   'SPE2': 1,
#   '31': 1,
#   'induces': 2,
#   'comprehensive': 1,
#   'promoter': 3,
#   'Particularly': 1,
#   'four': 3,
#   'classes': 1,
#   'ATP': 2,
#   'dependent': 5,
#   'remodelers': 1,
#   'facilitating': 3,
#   'spatial': 1,
#   'temporal': 2,
#   'remodeling': 8,
#   'All': 2,
#   'remodeler': 2,
#   'families': 1,
#   'consist': 2,
#   'SWI2': 2,
#   'SNF2family': 1,
#   'ATPase': 3,
#   'subunit': 1,
#   'featuring': 1,
#   '32': 3,
#   '33': 1,
#   'includes': 2,
#   'HSA': 2,
#   'helicase': 1,
#   'SANT': 2,
#   'post': 2,
#   'C': 27,
#   'terminal': 3,
#   'bromodomain': 1,
#   'Some': 1,
#   'subunits': 1,
#   'carry': 2,
#   'extra': 1,
#   'domains': 3,
#   'hBAF155': 1,
#   '170': 1,
#   'SWIRM': 1,
#   'hBAF60': 1,
#   'SWIB': 10,
#   'human': 4,
#   'polybromo': 1,
#   'bromodomains': 1,
#   'BAF60b': 4,
#   'generally': 2,
#   'known': 4,
#   'SWI': 13,
#   'B': 5,
#   'alternative': 3,
#   'form': 3,
#   'SNF': 10,
#   'Complex': 2,
#   '34': 2,
#   'BAF60a': 3,
#   'responsible': 2,
#   'cell': 3,
#   'cycle': 19,
#   'halting': 2,
#   'ability': 1,
#   'tune': 2,
#   'balance': 2,
#   'repair': 2,
#   'apoptosis': 4,
#   'induction': 2,
#   '35': 4,
#   '36': 3,
#   '37': 5,
#   'Recently': 1,
#   'related': 5,
#   'matrix': 2,
#   'regulator': 3,
#   'PfSWIB': 118,
#   'GenBank': 2,
#   'PF3D7_0611400': 1,
#   'characterized': 4,
#   'MDM2': 6,
#   'identified': 4,
#   'might': 7,
#   'trigger': 1,
#   'stage': 25,
#   'specific': 12,
#   'PCD': 2,
#   'transient': 2,
#   'localization': 2,
#   'removal': 3,
#   'parasites': 24,
#   '38': 7,
#   'Further': 2,
#   'revealed': 6,
#   'crucial': 3,
#   'survival': 6,
#   'growth': 7,
#   'also': 8,
#   'profound': 2,
#   'effects': 2,
#   'interacting': 2,
#   'unknown': 3,
#   'proteins': 10,
#   '39': 4,
#   '40': 7,
#   'remains': 2,
#   'unclear': 2,
#   'whether': 2,
#   'especially': 4,
#   'functional': 3,
#   'properties': 1,
#   'To': 6,
#   'address': 1,
#   'molecular': 2,
#   'mechanism': 2,
#   'propose': 1,
#   'new': 2,
#   'conditional': 2,
#   'knockdown': 5,
#   'system': 6,
#   'study': 12,
#   'function': 6,
#   'We': 4,
#   'dysfunction': 2,
#   'significant': 8,
#   'downregulation': 3,
#   'partial': 12,
#   'ring': 14,
#   'line': 20,
#   'well': 9,
#   'aberrant': 2,
#   'certain': 3,
#   'mature': 6,
#   '48': 5,
#   'h': 12,
#   'life': 13,
#   'reversion': 1,
#   'suggesting': 5,
#   'role': 5,
#   'addition': 4,
#   'could': 10,
#   'affect': 1,
#   'development': 1,
#   'provides': 1,
#   'better': 2,
#   'understanding': 2,
#   'regulatory': 2,
#   'complexes': 4,
#   'CRCs': 2,
#   'clonal': 3,
#   'insight': 1,
#   'contributing': 2,
#   'pathogenesis': 2,
#   'lines': 32,
#   '3D7': 21,
#   'first': 6,
#   'thawed': 2,
#   'established': 1,
#   'continuous': 2,
#   'cultivation': 2,
#   'vitro': 8,
#   'standard': 2,
#   'procedures': 1,
#   '41': 1,
#   'The': 36,
#   'follows': 3,
#   'isolates': 1,
#   'cultured': 4,
#   'RPMI': 1,
#   '1640': 1,
#   'medium': 4,
#   'Invitrogen': 3,
#   'Thermo': 3,
#   'Fisher': 3,
#   'Scientific': 4,
#   'Carlsbad': 3,
#   'CA': 5,
#   'USA': 7,
#   'containing': 4,
#   'mM': 4,
#   'Hepes': 1,
#   'l': 1,
#   'glutamine': 1,
#   '0': 36,
#   'hypoxanthine': 1,
#   'Sigma': 2,
#   'Aldrich': 2,
#   'Shanghai': 3,
#   'China': 3,
#   'mg': 1,
#   'ml': 3,
#   'gentamicin': 1,
#   'Albumax': 1,
#   'II': 4,
#   'serum': 1,
#   'type': 3,
#   'AB': 1,
#   'Changhai': 1,
#   'Hospital': 1,
#   'Second': 1,
#   'Military': 1,
#   'Medical': 1,
#   'University': 1,
#   'Cultures': 1,
#   'grown': 1,
#   'media': 1,
#   'O': 2,
#   'erythrocytes': 1,
#   'hematocrit': 1,
#   'CO': 1,
#   '92': 1,
#   'N': 2,
#   'obtain': 2,
#   'tightly': 2,
#   'synchronized': 5,
#   'percoll': 2,
#   'sorbitol': 3,
#   'synchronization': 1,
#   'method': 2,
#   'performed': 13,
#   '42': 1,
#   '43': 1,
#   'brief': 2,
#   'schizonts': 1,
#   'isolated': 1,
#   'cushion': 1,
#   'allowed': 1,
#   'invade': 1,
#   'fresh': 1,
#   'RBCs': 1,
#   'resulting': 4,
#   'rings': 2,
#   'subjected': 3,
#   'treatment': 3,
#   'min': 7,
#   'repeated': 2,
#   'twice': 2,
#   'culture': 7,
#   'washed': 1,
#   're': 6,
#   'suspended': 2,
#   'complete': 1,
#   'RBC': 2,
#   'final': 5,
#   'transfected': 8,
#   'originated': 1,
#   'clone': 13,
#   'DNA': 4,
#   'extraction': 1,
#   'using': 13,
#   'QIAamp': 1,
#   'Mini': 1,
#   'Kit': 1,
#   'Qiagen': 1,
#   'Hilden': 1,
#   'Germany': 1,
#   'high': 3,
#   'fidelity': 1,
#   'KOD': 1,
#   'plus': 1,
#   'Neo': 1,
#   'enzyme': 1,
#   'Toyobo': 1,
#   'Osaka': 1,
#   'Japan': 1,
#   'used': 16,
#   'PCR': 12,
#   'amplification': 4,
#   'detect': 3,
#   'endogenous': 5,
#   'locus': 7,
#   'integration': 6,
#   'HA': 21,
#   'FKBP': 25,
#   'LID': 24,
#   'reaction': 3,
#   'conditions': 2,
#   '95': 4,
#   'followed': 4,
#   'cycles': 4,
#   '50': 3,
#   '62': 2,
#   'extension': 2,
#   '65': 4,
#   'primers': 5,
#   'listed': 3,
#   'Additional': 26,
#   'file': 27,
#   'Table': 9,
#   'S1': 6,
#   'pLN': 7,
#   'ENR': 2,
#   'GFP': 2,
#   '44': 8,
#   'DQ813653': 1,
#   'modified': 5,
#   'deleting': 1,
#   'whole': 1,
#   'pfenr': 1,
#   'gfp': 1,
#   'cassette': 1,
#   'fragments': 1,
#   'ApaI': 2,
#   'BamHI': 1,
#   'multicloning': 2,
#   'construct': 2,
#   '6900': 1,
#   'bp': 1,
#   'calmodulin': 1,
#   'CaM': 1,
#   'fragment': 1,
#   'initially': 4,
#   'substituted': 1,
#   'kb': 3,
#   'terminus': 9,
#   'ASCI': 1,
#   'Three': 1,
#   'duplicates': 1,
#   'tag': 9,
#   'YPYDVPDYA': 1,
#   'ligated': 2,
#   'via': 2,
#   'linker': 1,
#   'AAAAVDAAAA': 1,
#   'vector': 1,
#   'transfect': 1,
#   'consists': 1,
#   'three': 6,
#   'tandem': 2,
#   'repeat': 2,
#   'sequences': 2,
#   'influenza': 2,
#   'hemagglutinin': 2,
#   'whereas': 4,
#   'comprised': 2,
#   'FK506': 1,
#   'and': 5,
#   'rapamycin': 2,
#   'amino': 2,
#   'acid': 2,
#   'degron': 3,
#   'fused': 3,
#   'Fig': 23,
#   '1a': 2,
#   '45': 5,
#   'Transfections': 1,
#   'ringstage': 1,
#   'mm': 1,
#   'BioRad': 2,
#   'Gene': 1,
#   'Pulser': 1,
#   'cuvettes': 1,
#   'Bio': 4,
#   'Rad': 4,
#   'Laboratories': 2,
#   'Hercules': 2,
#   '94547': 2,
#   'A': 6,
#   'minimum': 2,
#   '100': 2,
#   'μg': 1,
#   'recombinated': 1,
#   'plasmid': 3,
#   'purified': 2,
#   'electroporation': 1,
#   'GenePulse': 1,
#   'Xcell': 1,
#   'electroporator': 1,
#   '310': 1,
#   'V': 1,
#   'resistance': 3,
#   '950': 1,
#   'μF': 1,
#   'transfection': 4,
#   'less': 2,
#   'ms': 1,
#   'Positive': 1,
#   'BSD': 12,
#   'drug': 8,
#   'selection': 2,
#   'concentration': 2,
#   'nM': 1,
#   'subsequently': 12,
#   'applied': 3,
#   'maintained': 1,
#   'Those': 1,
#   'adopted': 1,
#   'carrying': 1,
#   'bsd': 2,
#   'would': 2,
#   'offer': 1,
#   'level': 8,
#   'culturing': 4,
#   'days': 4,
#   'subsequent': 3,
#   'cycling': 3,
#   'select': 1,
#   'stable': 4,
#   'crossover': 2,
#   'initial': 1,
#   'obtained': 7,
#   'mixture': 1,
#   'integrated': 12,
#   'Therefore': 2,
#   'mode': 1,
#   'screening': 8,
#   'introduced': 2,
#   'enrich': 2,
#   'original': 1,
#   'absence': 7,
#   'weeks': 4,
#   'µg': 1,
#   'therefore': 3,
#   'possibly': 1,
#   'sorted': 1,
#   'rounds': 1,
#   '1b': 2,
#   'After': 1,
#   'two': 12,
#   'events': 5,
#   'Primers': 1,
#   'P2': 1,
#   'P4': 1,
#   'P5': 1,
#   'upstream': 1,
#   'downstream': 1,
#   'fusion': 13,
#   'respectively': 5,
#   'Fn': 1,
#   'forward': 1,
#   'primer': 2,
#   'order': 3,
#   'clones': 9,
#   'utilized': 1,
#   'assay': 4,
#   'serial': 2,
#   'dilution': 4,
#   '96': 7,
#   'plates': 3,
#   'detailed': 1,
#   'previously': 5,
#   '46': 1,
#   'transfections': 2,
#   'C2': 6,
#   'B10': 4,
#   'detected': 2,
#   'screened': 3,
#   'extended': 1,
#   'testing': 3,
#   'described': 4,
#   'see': 1,
#   '94': 2,
#   '54': 3,
#   'analyze': 2,
#   'extracts': 1,
#   'prepared': 2,
#   'saponin': 1,
#   'SDS': 2,
#   'loading': 1,
#   'buffer': 1,
#   'separated': 1,
#   'PAGE': 1,
#   'gel': 1,
#   'western': 3,
#   'blot': 2,
#   'analysis': 16,
#   'Total': 1,
#   'An': 2,
#   'antibody': 1,
#   'aldolase': 1,
#   '1000': 2,
#   'Roche': 1,
#   'Indianapolis': 1,
#   'positive': 1,
#   'Rabbit': 1,
#   'anti': 1,
#   'Abcam': 1,
#   'Cambridge': 1,
#   'UK': 1,
#   'identify': 2,
#   'enhanced': 1,
#   'chemiluminescence': 1,
#   'ECL': 1,
#   'blotting': 2,
#   'kit': 1,
#   'GE': 1,
#   'Healthcare': 1,
#   'Uppsala': 1,
#   'Sweden': 1,
#   'develop': 1,
#   'blots': 1,
#   'theoretical': 1,
#   'weight': 1,
#   '92kD': 1,
#   '5kD': 1,
#   '22kD': 1,
#   'graylevel': 1,
#   'image': 1,
#   'procedure': 1,
#   'implemented': 2,
#   'ImageJ': 1,
#   'software': 1,
#   'Statistical': 1,
#   'significance': 2,
#   'determined': 2,
#   '05': 11,
#   '01': 3,
#   'Synchronized': 1,
#   'invasion': 2,
#   'collected': 2,
#   'diluted': 3,
#   'parasitemia': 8,
#   'Each': 1,
#   'divided': 2,
#   'wells': 2,
#   'cultures': 1,
#   'plate': 1,
#   'µl': 1,
#   'pellets': 1,
#   'Shield1': 1,
#   'ethanol': 1,
#   'Clontech': 1,
#   'Mountain': 1,
#   'View': 1,
#   'added': 1,
#   'μM': 2,
#   'Consequently': 1,
#   'PfSWIBΔ': 1,
#   'shield1': 15,
#   'induced': 7,
#   'sh': 6,
#   'subject': 2,
#   'counted': 1,
#   'every': 1,
#   'rate': 1,
#   'compared': 6,
#   'statistically': 1,
#   'way': 4,
#   'ANOVA': 2,
#   'Bonferroni': 1,
#   's': 5,
#   'comparison': 4,
#   'test': 3,
#   'Growth': 1,
#   'curve': 3,
#   'triplicate': 1,
#   'transcription': 11,
#   'individual': 2,
#   'pairs': 1,
#   'published': 1,
#   'elsewhere': 1,
#   '47': 1,
#   'S2': 4,
#   'qPCR': 11,
#   'assays': 2,
#   'RNA': 18,
#   'synchronous': 1,
#   'extracted': 1,
#   'TRIzol': 1,
#   'reagent': 1,
#   'cDNA': 1,
#   'accordance': 1,
#   'manufacturer': 1,
#   'recommendations': 1,
#   'Thermofisher': 1,
#   'fold': 10,
#   'change': 14,
#   'experimental': 2,
#   'reference': 3,
#   'groups': 4,
#   'calculated': 1,
#   'ΔΔCq': 1,
#   'QuantStudio': 1,
#   'Flex': 1,
#   'Real': 1,
#   'Time': 1,
#   'System': 1,
#   'Applied': 1,
#   'Biosystems': 1,
#   'Singapore': 1,
#   'program': 1,
#   'Seryl': 1,
#   'tRNA': 1,
#   'synthetase': 1,
#   'normalize': 1,
#   'data': 8,
#   'statistical': 2,
#   'tailed': 1,
#   'Student': 1,
#   't': 1,
#   'seq': 14,
#   'screen': 1,
#   'differentially': 6,
#   'carried': 1,
#   'duplicate': 2,
#   'genome': 5,
#   'transcript': 1,
#   'information': 1,
#   'PlasmoDB': 4,
#   'http': 2,
#   'plasm': 2,
#   'odb': 2,
#   'org': 2,
#   'aligner': 1,
#   'STAR': 1,
#   'v2': 1,
#   '3a': 1,
#   '49': 1,
#   'create': 1,
#   'catalog': 1,
#   'based': 3,
#   'files': 1,
#   'fasta': 2,
#   'GFF3': 1,
#   'annotation': 1,
#   '34_Pfalcipa': 1,
#   'rum3D7_Genome': 1,
#   '34_Pfalciparum3D7': 1,
#   'gff': 1,
#   'FastQC': 1,
#   'v0': 2,
#   'quality': 2,
#   'reads': 2,
#   'qualified': 1,
#   'mapped': 1,
#   'aligned': 1,
#   'Reads': 1,
#   'mapping': 1,
#   'q': 1,
#   'SAM': 1,
#   'tools': 1,
#   'Heatmaps': 1,
#   'profiles': 2,
#   'created': 1,
#   'R': 7,
#   'package': 4,
#   'edgeR': 3,
#   'Hierarchical': 1,
#   'clustering': 4,
#   'minus': 1,
#   'Pearson': 1,
#   'correlation': 5,
#   'metric': 1,
#   'average': 1,
#   'linkage': 1,
#   'Line': 1,
#   'plots': 1,
#   'generated': 1,
#   'ggplot2': 1,
#   '51': 1,
#   'variance': 1,
#   'like': 1,
#   'differential': 2,
#   'summarized': 1,
#   'read': 1,
#   'counts': 1,
#   'per': 1,
#   'genomic': 1,
#   'feature': 2,
#   'Counts': 1,
#   '52': 1,
#   'ALDEx2': 1,
#   '53': 1,
#   'greater': 1,
#   'lower': 1,
#   'FDR': 3,
#   'selected': 8,
#   'filters': 1,
#   'defining': 1,
#   'sets': 1,
#   'harbored': 1,
#   'antibiotic': 1,
#   'Blasticidin': 2,
#   'S': 2,
#   'pink': 1,
#   'tags': 1,
#   'red': 4,
#   'blue': 1,
#   'green': 1,
#   'b': 1,
#   'Drug': 1,
#   'indicate': 1,
#   'presence': 5,
#   'Day': 2,
#   'details': 1,
#   'detecting': 2,
#   'provided': 1,
#   'Methods': 1,
#   'Due': 1,
#   'low': 3,
#   'proficiency': 2,
#   'inserting': 1,
#   'full': 2,
#   'length': 2,
#   'cloned': 1,
#   'recombinant': 2,
#   'plasmids': 1,
#   'forming': 1,
#   'Through': 1,
#   'homologous': 1,
#   'recombination': 1,
#   'caused': 2,
#   'event': 1,
#   'transfecting': 1,
#   'strain': 1,
#   'deaminase': 1,
#   'contains': 1,
#   'FK506and': 1,
#   'ligand': 1,
#   'degradation': 3,
#   'designed': 1,
#   'Figure': 18,
#   'shows': 3,
#   'identification': 1,
#   'Stable': 1,
#   'finally': 1,
#   'cloning': 1,
#   'Since': 1,
#   'exhibited': 5,
#   'stability': 1,
#   'reproducibility': 1,
#   'detection': 1,
#   'rather': 1,
#   'present': 5,
#   'Western': 2,
#   '2000': 1,
#   'According': 5,
#   'theoretically': 1,
#   'small': 2,
#   'molecule': 2,
#   'Alternatively': 2,
#   'thereby': 1,
#   'substituting': 1,
#   'triggering': 1,
#   'rapid': 1,
#   'As': 2,
#   'may': 4,
#   'take': 1,
#   'exert': 1,
#   'inhibition': 1,
#   'trophozoite': 9,
#   'within': 8,
#   'third': 7,
#   'samples': 3,
#   'GCA': 3,
#   '2a': 2,
#   'indicated': 1,
#   ...},)

# %%
text_clean.take(2, npartitions=2)
# Out:
# (['Plasmodium',
#   'falciparum',
#   'which',
#   'causes',
#   'malignant',
#   'malaria',
#   'such',
#   'as',
#   'cerebral',
#   'malaria',
#   'CM',
#   'or',
#   'pregnancy',
#   'associated',
#   'malaria',
#   'PAM',
#   '1',
#   '2',
#   'is',
#   'the',
#   'cause',
#   'of',
#   'death',
#   'to',
#   '435',
#   '000',
#   'individuals',
#   'annually',
#   '3',
#   'Plasmodium',
#   'falciparum',
#   'erythrocyte',
#   'membrane',
#   'protein',
#   '1',
#   'PfEMP1',
#   'which',
#   'is',
#   'encoded',
#   'by',
#   'the',
#   'var',
#   'gene',
#   'family',
#   'comprising',
#   'approximately',
#   '60',
#   'members',
#   'is',
#   'the',
#   'major',
#   'virulence',
#   'factor',
#   'involved',
#   'in',
#   'the',
#   'antigenic',
#   'variation',
#   'and',
#   'clinical',
#   'pathogenicity',
#   'of',
#   'falciparum',
#   'malaria',
#   '4',
#   '5',
#   'It',
#   'is',
#   'remarkable',
#   'that',
#   'the',
#   'expression',
#   'of',
#   'var',
#   'family',
#   'members',
#   'is',
#   'mutually',
#   'exclusive',
#   'For',
#   'each',
#   'parasite',
#   'at',
#   'a',
#   'time',
#   'only',
#   'one',
#   'or',
#   'a',
#   'few',
#   'var',
#   'genes',
#   'are',
#   'expressed',
#   'while',
#   'the',
#   'remaining',
#   'members',
#   'are',
#   'silenced',
#   '6',
#   '7',
#   'In',
#   'each',
#   'generation',
#   'P',
#   'falciparum',
#   'is',
#   'able',
#   'to',
#   'express',
#   'different',
#   'var',
#   'genes',
#   'and',
#   'the',
#   'switches',
#   'in',
#   'var',
#   'gene',
#   'expression',
#   'lead',
#   'to',
#   'antigenic',
#   'variation',
#   'of',
#   'PfEMP1',
#   'which',
#   'results',
#   'in',
#   'immune',
#   'evasion',
#   'and',
#   'chronic',
#   'infection',
#   '8',
#   '9',
#   '10',
#   '11',
#   'This',
#   'process',
#   'has',
#   'proven',
#   'to',
#   'be',
#   'mediated',
#   'by',
#   'epigenetic',
#   'mechanisms',
#   'including',
#   'chromatin',
#   'modification',
#   'nuclear',
#   'architecture',
#   'and',
#   'gene',
#   'relocation',
#   '12',
#   '13',
#   'It',
#   'has',
#   'been',
#   'shown',
#   'that',
#   'the',
#   'single',
#   'active',
#   'var',
#   'gene',
#   'is',
#   'enriched',
#   'in',
#   'euchromatic',
#   'modifications',
#   'such',
#   'as',
#   'histone',
#   '3',
#   'lysine',
#   '9',
#   'acetylation',
#   'H3K9ac',
#   'and',
#   'histone',
#   '3',
#   'lysine',
#   '4',
#   'trimethylation',
#   'H3K4me3',
#   'particularly',
#   'near',
#   'the',
#   'transcriptional',
#   'start',
#   'site',
#   'TSS',
#   '14',
#   'while',
#   'the',
#   'silent',
#   'var',
#   'genes',
#   'are',
#   'usually',
#   'enriched',
#   'in',
#   'the',
#   'heterochromatin',
#   'marker',
#   'histone',
#   '3',
#   'lysine9',
#   'trimethylation',
#   'H3K9me3',
#   'in',
#   'the',
#   '5',
#   'UTR',
#   'or',
#   'the',
#   'coding',
#   'sequence',
#   '14',
#   '15',
#   '16',
#   '17',
#   'In',
#   'this',
#   'process',
#   'histone',
#   'modifying',
#   'enzymes',
#   'such',
#   'as',
#   'PfMYST',
#   'PfGCN5',
#   'PfSIR2',
#   'and',
#   'PfSET',
#   'have',
#   'been',
#   'considered',
#   'important',
#   'for',
#   'epigenetic',
#   'control',
#   'of',
#   'reversible',
#   'histone',
#   'modifications',
#   'according',
#   'to',
#   'previous',
#   'studies',
#   '12',
#   '13',
#   'PfMYST',
#   'a',
#   'putative',
#   'histone',
#   'acetyltransferases',
#   'HATs',
#   'in',
#   'P',
#   'falciparum',
#   'is',
#   'capable',
#   'of',
#   'acetylating',
#   'multiple',
#   'lysines',
#   'on',
#   'H4',
#   '18',
#   '19',
#   'while',
#   'an',
#   'orthologue',
#   'of',
#   'the',
#   'yeast',
#   'HAT',
#   'PfGCN5',
#   'influences',
#   'acetylation',
#   'of',
#   'H3K9',
#   'and',
#   'K14',
#   'both',
#   'are',
#   'essential',
#   'marks',
#   'of',
#   'gene',
#   'activation',
#   '18',
#   '20',
#   'Two',
#   'paralogues',
#   'of',
#   'the',
#   'class',
#   'III',
#   'HDAC',
#   'histone',
#   'deacetylases',
#   'Sir2',
#   'play',
#   'key',
#   'roles',
#   'in',
#   'maintaining',
#   'heterochromatin',
#   'and',
#   'mutually',
#   'exclusive',
#   'var',
#   'gene',
#   'expression',
#   '15',
#   '21',
#   '22',
#   'PfSir2A',
#   'deacetylates',
#   'H3K9ac',
#   'H3K14ac',
#   'and',
#   'H4K16ac',
#   '23',
#   'and',
#   'is',
#   'more',
#   'important',
#   'in',
#   'silencing',
#   'subtelomeric',
#   'var',
#   'genes',
#   'such',
#   'as',
#   'upsA',
#   'upsEand',
#   'upsC',
#   'subtype',
#   'vars',
#   'In',
#   'contrast',
#   'PfSir2B',
#   'silences',
#   'upsB',
#   'vars',
#   '22',
#   'Furthermore',
#   'a',
#   'total',
#   'of',
#   'ten',
#   'P',
#   'falciparum',
#   'histone',
#   'lysine',
#   'methyltransferases',
#   'HKMTs',
#   'belonging',
#   'to',
#   'the',
#   'SET',
#   'domain',
#   'family',
#   'have',
#   'been',
#   'found',
#   'in',
#   'P',
#   'falciparum',
#   '18',
#   '24',
#   '25',
#   'PfSET10',
#   'localizes',
#   'to',
#   'a',
#   'specialized',
#   'region',
#   'at',
#   'the',
#   'nuclear',
#   'periphery',
#   'with',
#   'the',
#   'active',
#   'vars',
#   'such',
#   'as',
#   'H3K4me4',
#   'transferase',
#   '26',
#   'Plasmodium',
#   'falciparum',
#   'variant',
#   'silencing',
#   'SET',
#   'gene',
#   'PfSETvs',
#   'controls',
#   'the',
#   'H3K36me3',
#   'on',
#   'var',
#   'genes',
#   'silencing',
#   'var',
#   'genes',
#   '27',
#   'Moreover',
#   'subnuclear',
#   'architecture',
#   'contributes',
#   'to',
#   'the',
#   'regulation',
#   'of',
#   'var',
#   'gene',
#   'expression',
#   '13',
#   'var',
#   'genes',
#   'are',
#   'by',
#   'default',
#   'silent',
#   'since',
#   'they',
#   'are',
#   'located',
#   'at',
#   'the',
#   'nuclear',
#   'periphery',
#   '28',
#   'However',
#   'active',
#   'var',
#   'promoters',
#   'seem',
#   'to',
#   'occupy',
#   'a',
#   'privileged',
#   'expression',
#   'site',
#   'of',
#   'this',
#   'region',
#   'making',
#   'it',
#   'permissive',
#   'to',
#   'transcribe',
#   '21',
#   'PF11_0091',
#   'an',
#   'ApiAP2',
#   'member',
#   'binds',
#   'a',
#   'conserved',
#   'motif',
#   'in',
#   'var',
#   'introns',
#   'mediates',
#   'episomal',
#   'anchoring',
#   'towards',
#   'the',
#   'nuclear',
#   'periphery',
#   'and',
#   'recruiting',
#   'an',
#   'actin',
#   'protein',
#   'complex',
#   'and',
#   'polymerized',
#   'nuclear',
#   'actin',
#   'de',
#   'represses',
#   'silent',
#   'var',
#   'genes',
#   '29',
#   'On',
#   'the',
#   'other',
#   'hand',
#   'various',
#   'trans',
#   'factors',
#   'are',
#   'intimately',
#   'involved',
#   'in',
#   'regulating',
#   'chromatin',
#   'structure',
#   'and',
#   'gene',
#   'activity',
#   'PfAlbas',
#   'contribute',
#   'to',
#   'heterochromatin',
#   'structure',
#   'and',
#   'regulation',
#   'of',
#   'var',
#   'gene',
#   'expression',
#   '30',
#   'PfSIP2',
#   'another',
#   'ApiAP2',
#   'member',
#   'is',
#   'involved',
#   'in',
#   'the',
#   'recruitment',
#   'and',
#   'organization',
#   'of',
#   'subtelomeric',
#   'heterochromatin',
#   'through',
#   'binding',
#   'to',
#   'SPE2',
#   '31',
#   'and',
#   'induces',
#   'a',
#   'comprehensive',
#   'silencing',
#   'of',
#   'a',
#   'var',
#   'promoter',
#   'Particularly',
#   'four',
#   'major',
#   'classes',
#   'of',
#   'ATP',
#   'dependent',
#   'chromatin',
#   'remodelers',
#   'had',
#   'been',
#   'found',
#   'in',
#   'P',
#   'falciparum',
#   'facilitating',
#   'the',
#   'spatial',
#   'and',
#   'temporal',
#   'remodeling',
#   'of',
#   'chromatin',
#   '13',
#   'All',
#   'these',
#   'remodeler',
#   'families',
#   'consist',
#   'of',
#   'a',
#   'SWI2',
#   'SNF2family',
#   'ATPase',
#   'subunit',
#   'featuring',
#   'an',
#   'ATPase',
#   'domain',
#   '32',
#   '33',
#   'which',
#   'includes',
#   'an',
#   'HSA',
#   'helicase',
#   'SANT',
#   'a',
#   'post',
#   'HSA',
#   'and',
#   'a',
#   'C',
#   'terminal',
#   'bromodomain',
#   'Some',
#   'other',
#   'conserved',
#   'subunits',
#   'carry',
#   'extra',
#   'conserved',
#   'domains',
#   'such',
#   'as',
#   'hBAF155',
#   '170',
#   'SANT',
#   'SWIRM',
#   'hBAF60',
#   'SWIB',
#   'and',
#   'human',
#   'polybromo',
#   'multiple',
#   'bromodomains',
#   'BAF60b',
#   'is',
#   'generally',
#   'known',
#   'as',
#   'SWI',
#   'B',
#   'or',
#   'SWIB',
#   'an',
#   'alternative',
#   'form',
#   'of',
#   'the',
#   'SWI',
#   'SNF',
#   'complex',
#   'Complex',
#   'B',
#   '34',
#   'while',
#   'human',
#   'BAF60a',
#   'protein',
#   'of',
#   'SWI',
#   'SNF',
#   'complex',
#   'is',
#   'responsible',
#   'for',
#   'facilitating',
#   'cell',
#   'cycle',
#   'halting',
#   'and',
#   'has',
#   'the',
#   'ability',
#   'to',
#   'tune',
#   'the',
#   'balance',
#   'between',
#   'repair',
#   'and',
#   'apoptosis',
#   'induction',
#   '35',
#   '36',
#   '37',
#   'Recently',
#   'a',
#   'SWI',
#   'SNF',
#   'related',
#   'matrix',
#   'associated',
#   'actin',
#   'dependent',
#   'regulator',
#   'of',
#   'chromatin',
#   'PfSWIB',
#   'GenBank',
#   'PF3D7_0611400',
#   'which',
#   'is',
#   'characterized',
#   'by',
#   'its',
#   'SWIB',
#   'MDM2',
#   'domain',
#   'SWI',
#   'complex',
#   'BAF60b',
#   'domain',
#   'has',
#   'been',
#   'identified',
#   'in',
#   'P',
#   'falciparum',
#   'PfSWIB',
#   'might',
#   'trigger',
#   'stage',
#   'specific',
#   'PCD',
#   'by',
#   'which',
#   'transient',
#   'nuclear',
#   'localization',
#   'causes',
#   'removal',
#   'of',
#   'these',
#   'parasites',
#   '38',
#   'Further',
#   'studies',
#   'revealed',
#   'that',
#   'PfSWIB',
#   'was',
#   'not',
#   'only',
#   'crucial',
#   'for',
#   'the',
#   'survival',
#   'and',
#   'growth',
#   'of',
#   'the',
#   'parasite',
#   'but',
#   'also',
#   'had',
#   'profound',
#   'effects',
#   'on',
#   'the',
#   'parasite',
#   'by',
#   'interacting',
#   'with',
#   'other',
#   'unknown',
#   'proteins',
#   '38',
#   '39',
#   '40',
#   'However',
#   'it',
#   'remains',
#   'unclear',
#   'whether',
#   'PfSWIB',
#   'is',
#   'involved',
#   'in',
#   'transcriptional',
#   'regulation',
#   'of',
#   'virulence',
#   'gene',
#   'especially',
#   'vars',
#   'and',
#   'its',
#   'functional',
#   'properties',
#   'To',
#   'address',
#   'the',
#   'molecular',
#   'mechanism',
#   'of',
#   'PfSWIB',
#   'we',
#   'propose',
#   'a',
#   'new',
#   'conditional',
#   'knockdown',
#   'system',
#   'to',
#   'study',
#   'the',
#   'function',
#   'and',
#   'mechanism',
#   'of',
#   'chromatin',
#   'remodeler',
#   'PfSWIB',
#   'in',
#   'regulating',
#   'var',
#   'gene',
#   'expression',
#   'We',
#   'found',
#   'that',
#   'the',
#   'dysfunction',
#   'of',
#   'PfSWIB',
#   'might',
#   'lead',
#   'to',
#   'a',
#   'significant',
#   'downregulation',
#   'of',
#   'upsA',
#   'upsC',
#   'and',
#   'partial',
#   'upsB',
#   'var',
#   'genes',
#   'at',
#   'the',
#   'ring',
#   'stage',
#   'in',
#   'a',
#   'PfSWIB',
#   'knockdown',
#   'line',
#   'as',
#   'well',
#   'as',
#   'the',
#   'aberrant',
#   'expression',
#   'of',
#   'certain',
#   'var',
#   'genes',
#   'at',
#   'the',
#   'mature',
#   'stage',
#   'in',
#   'a',
#   'single',
#   '48',
#   'h',
#   'life',
#   'cycle',
#   'of',
#   'P',
#   'falciparum',
#   'which',
#   'was',
#   'characterized',
#   'by',
#   'the',
#   'reversion',
#   'of',
#   'transcriptional',
#   'downregulation',
#   'of',
#   'upsA',
#   'and',
#   'partial',
#   'upsB',
#   'upsC',
#   'var',
#   'genes',
#   'suggesting',
#   'that',
#   'PfSWIB',
#   'might',
#   'play',
#   'a',
#   'key',
#   'role',
#   'on',
#   'var',
#   'gene',
#   'regulating',
#   'In',
#   'addition',
#   'PfSWIB',
#   'knockdown',
#   'could',
#   'affect',
#   'the',
#   'growth',
#   'and',
#   'development',
#   'of',
#   'parasite',
#   'This',
#   'study',
#   'provides',
#   'a',
#   'better',
#   'understanding',
#   'of',
#   'the',
#   'regulatory',
#   'function',
#   'of',
#   'chromatin',
#   'remodeling',
#   'complexes',
#   'CRCs',
#   'in',
#   'regulating',
#   'the',
#   'clonal',
#   'variation',
#   'of',
#   'var',
#   'genes',
#   'and',
#   'an',
#   'essential',
#   'insight',
#   'into',
#   'the',
#   'regulation',
#   'of',
#   'the',
#   'major',
#   'virulence',
#   'gene',
#   'family',
#   'contributing',
#   'to',
#   'the',
#   'pathogenesis',
#   'in',
#   'malaria',
#   'parasites',
#   'Plasmodium',
#   'falciparum',
#   'lines',
#   '3D7',
#   'PfSWIB',
#   'and',
#   'PfSWIB',
#   'were',
#   'first',
#   'thawed',
#   'and',
#   'established',
#   'for',
#   'continuous',
#   'cultivation',
#   'in',
#   'vitro',
#   'according',
#   'to',
#   'standard',
#   'procedures',
#   '41',
#   'The',
#   'cultivation',
#   'was',
#   'as',
#   'follows',
#   'thawed',
#   'isolates',
#   'were',
#   'cultured',
#   'in',
#   'RPMI',
#   '1640',
#   'medium',
#   'Invitrogen',
#   'Thermo',
#   'Fisher',
#   'Scientific',
#   'Carlsbad',
#   'CA',
#   'USA',
#   'containing',
#   '25',
#   'mM',
#   'Hepes',
#   '2',
#   'mM',
#   'l',
#   ...],
#  ['The',
#   'incidence',
#   'of',
#   'health',
#   'care',
#   'associated',
#   'infection',
#   'HCAI',
#   'caused',
#   'by',
#   'multidrug',
#   'resistant',
#   'bacteria',
#   'has',
#   'gradually',
#   'risen',
#   'during',
#   'the',
#   'last',
#   'decade',
#   'especially',
#   'in',
#   'immunocompromised',
#   'patients',
#   '1',
#   '2',
#   'The',
#   'most',
#   'common',
#   'causative',
#   'agents',
#   'of',
#   'HCAI',
#   'in',
#   'the',
#   'United',
#   'States',
#   'are',
#   'the',
#   'Gram',
#   'positive',
#   'bacteria',
#   'Staphylococcus',
#   'aureus',
#   'and',
#   'Enterococcus',
#   '3',
#   'Methicillin',
#   'oxacillin',
#   'resistant',
#   'S',
#   'aureus',
#   'MRSA',
#   'is',
#   'of',
#   'particular',
#   'concern',
#   'because',
#   'patients',
#   'with',
#   'MRSA',
#   'infection',
#   'tend',
#   'to',
#   'have',
#   'higher',
#   'mortality',
#   'rates',
#   'longer',
#   'hospital',
#   'stays',
#   'and',
#   'higher',
#   'health',
#   'careassociated',
#   'costs',
#   'than',
#   'patients',
#   'with',
#   'methicillin',
#   'susceptible',
#   'S',
#   'aureus',
#   'infections',
#   '1',
#   '4',
#   'In',
#   'addition',
#   'DiazGranados',
#   'et',
#   'al',
#   '5',
#   'found',
#   'that',
#   'the',
#   'mortality',
#   'rate',
#   'among',
#   'patients',
#   'with',
#   'vancomycin',
#   'resistant',
#   'enterococci',
#   'VREs',
#   'infection',
#   'was',
#   'significantly',
#   'higher',
#   'than',
#   'that',
#   'among',
#   'patients',
#   'with',
#   'vancomycin',
#   'susceptible',
#   'Enterococcus',
#   'infections',
#   'Taiwan',
#   'is',
#   'no',
#   'exception',
#   'and',
#   'VRE',
#   'and',
#   'MRSA',
#   'infections',
#   'have',
#   'become',
#   'emerging',
#   'infectious',
#   'diseases',
#   '6e10',
#   'Antibiotic',
#   'use',
#   'is',
#   'one',
#   'of',
#   'the',
#   'risk',
#   'factors',
#   'for',
#   'antibiotic',
#   'resistance',
#   'among',
#   'bacterial',
#   'species',
#   'however',
#   'the',
#   'nature',
#   'of',
#   'this',
#   'relationship',
#   'is',
#   'complicated',
#   'Although',
#   'several',
#   'studies',
#   'have',
#   'examined',
#   'the',
#   'relationship',
#   'between',
#   'antimicrobial',
#   'consumption',
#   'and',
#   'antibiotic',
#   'resistance',
#   'the',
#   'findings',
#   'were',
#   'inconsistent',
#   'possibly',
#   'due',
#   'to',
#   'differences',
#   'in',
#   'resistance',
#   'profiles',
#   'as',
#   'well',
#   'as',
#   'due',
#   'to',
#   'differences',
#   'in',
#   'antibiotic',
#   'prescribing',
#   'practices',
#   'in',
#   'different',
#   'countries',
#   '11e18',
#   'In',
#   'those',
#   'studies',
#   'the',
#   'use',
#   'of',
#   'glycopeptides',
#   'extended',
#   'spectrum',
#   'cephalosporins',
#   'and',
#   'fluoroquinolones',
#   'was',
#   'demonstrated',
#   'to',
#   'be',
#   'associated',
#   'with',
#   'the',
#   'prevalence',
#   'of',
#   'MRSA',
#   'and',
#   'VRE',
#   '12e18',
#   'Few',
#   'studies',
#   'however',
#   'have',
#   'investigated',
#   'the',
#   'relationship',
#   'between',
#   'the',
#   'use',
#   'of',
#   'linezolid',
#   'or',
#   'fusidic',
#   'acid',
#   'and',
#   'the',
#   'prevalence',
#   'of',
#   'MRSA',
#   'and',
#   'VRE',
#   'In',
#   'addition',
#   'the',
#   'association',
#   'between',
#   'the',
#   'consumption',
#   'of',
#   'tigecycline',
#   'a',
#   'novel',
#   'anti',
#   'Gram',
#   'positive',
#   'agent',
#   'derived',
#   'from',
#   'minocycline',
#   'that',
#   'has',
#   'been',
#   'shown',
#   'to',
#   'be',
#   'effective',
#   'against',
#   'many',
#   'Gram',
#   'negative',
#   'rods',
#   'as',
#   'well',
#   'as',
#   'Gram',
#   'positive',
#   'cocci',
#   'and',
#   'the',
#   'prevalence',
#   'of',
#   'MRSA',
#   'and',
#   'VRE',
#   'has',
#   'never',
#   'been',
#   'studied',
#   '19',
#   'Similarly',
#   'no',
#   'studies',
#   'have',
#   'so',
#   'far',
#   'investigated',
#   'the',
#   'association',
#   'between',
#   'the',
#   'prevalence',
#   'of',
#   'MRSA',
#   'and',
#   'VRE',
#   'and',
#   'the',
#   'consumption',
#   'of',
#   'daptomycin',
#   'an',
#   'anti',
#   'MRSA',
#   'antibiotic',
#   'that',
#   'has',
#   'been',
#   'approved',
#   'by',
#   'the',
#   'U',
#   'S',
#   'Food',
#   'and',
#   'Drug',
#   'Administration',
#   'for',
#   'the',
#   'treatment',
#   'of',
#   'complicated',
#   'skin',
#   'and',
#   'skin',
#   'structure',
#   'infections',
#   'and',
#   'bacteremia',
#   'due',
#   'to',
#   'MRSA',
#   '20',
#   '21',
#   'In',
#   'this',
#   'study',
#   'we',
#   'investigated',
#   'the',
#   'correlation',
#   'between',
#   'consumption',
#   'of',
#   'antibiotics',
#   'including',
#   'vancomycin',
#   'teicoplanin',
#   'linezolid',
#   'tigecycline',
#   'fusidic',
#   'acid',
#   'and',
#   'daptomycin',
#   'and',
#   'the',
#   'incidence',
#   'of',
#   'HCAI',
#   'MRSA',
#   'and',
#   'HCAI',
#   'VRE',
#   'during',
#   'the',
#   'period',
#   'from',
#   '2000',
#   'to',
#   '2010',
#   'at',
#   'a',
#   'medical',
#   'center',
#   'in',
#   'Taiwan',
#   'The',
#   'National',
#   'Taiwan',
#   'University',
#   'Hospital',
#   'NTUH',
#   'is',
#   'a',
#   '2500bed',
#   'academically',
#   'affiliated',
#   'medical',
#   'center',
#   'that',
#   'provides',
#   'both',
#   'primary',
#   'and',
#   'tertiary',
#   'care',
#   'in',
#   'northern',
#   'Taiwan',
#   'The',
#   'number',
#   'of',
#   'annual',
#   'inpatient',
#   'days',
#   'at',
#   'the',
#   'hospital',
#   'increased',
#   'from',
#   '624',
#   '675',
#   'in',
#   '2000',
#   'to',
#   '763',
#   '772',
#   'in',
#   '2010',
#   'Linezolid',
#   'and',
#   'fusidic',
#   'acid',
#   'were',
#   'introduced',
#   'into',
#   'the',
#   'hospital',
#   'formulary',
#   'in',
#   '2002',
#   'Tigecycline',
#   'and',
#   'daptomycin',
#   'have',
#   'been',
#   'prescribed',
#   'at',
#   'the',
#   'NTUH',
#   'since',
#   '2007',
#   'and',
#   '2009',
#   'respectively',
#   'Some',
#   'of',
#   'the',
#   'data',
#   'analyzed',
#   'in',
#   'this',
#   'study',
#   'were',
#   'included',
#   'in',
#   'a',
#   'previous',
#   'study',
#   '16',
#   '17',
#   'Bacterial',
#   'isolates',
#   'Data',
#   'on',
#   'the',
#   'susceptibilities',
#   'of',
#   'S',
#   'aureus',
#   'to',
#   'oxacillin',
#   'were',
#   'collected',
#   'during',
#   'the',
#   'period',
#   'from',
#   '2000',
#   'to',
#   '2010',
#   'These',
#   'isolates',
#   'were',
#   'nonduplicate',
#   'and',
#   'isolates',
#   'of',
#   'each',
#   'species',
#   'from',
#   'each',
#   'patient',
#   'recovered',
#   'within',
#   '7',
#   'days',
#   'were',
#   'considered',
#   'as',
#   'a',
#   'single',
#   'isolate',
#   'Susceptibility',
#   'testing',
#   'for',
#   'S',
#   'aureus',
#   'and',
#   'Enterococcus',
#   'species',
#   'followed',
#   'the',
#   'Clinical',
#   'and',
#   'Laboratory',
#   'Standards',
#   'Institute',
#   'guidelines',
#   '22',
#   'S',
#   'aureus',
#   'ATCC',
#   '25923',
#   'was',
#   'used',
#   'as',
#   'the',
#   'control',
#   'strain',
#   'for',
#   'routine',
#   'disk',
#   'susceptibility',
#   'testing',
#   '22',
#   'Methicillin',
#   'resistance',
#   'among',
#   'S',
#   'aureus',
#   'isolates',
#   'was',
#   'routinely',
#   'screened',
#   'by',
#   'measuring',
#   'their',
#   'growth',
#   'on',
#   'oxacillin',
#   '6',
#   'mg',
#   'L',
#   'in',
#   '2',
#   'NaCl',
#   'containing',
#   'trypticase',
#   'soy',
#   'agar',
#   'plate',
#   'that',
#   'had',
#   'been',
#   'incubated',
#   'in',
#   'ambient',
#   'air',
#   'at',
#   '35',
#   'C',
#   'for',
#   '24',
#   'hours',
#   '22',
#   '23',
#   'Vancomycin',
#   'resistance',
#   'among',
#   'Enterococcus',
#   'species',
#   'was',
#   'confirmed',
#   'by',
#   'growth',
#   'of',
#   'the',
#   'isolate',
#   'on',
#   'a',
#   'brain',
#   'heart',
#   'infusion',
#   'agar',
#   'plate',
#   'containing',
#   'vancomycin',
#   '6',
#   'mg',
#   'L',
#   'that',
#   'had',
#   'been',
#   'incubated',
#   'in',
#   'ambient',
#   'air',
#   'at',
#   '35',
#   'C',
#   'for',
#   '24',
#   'hours',
#   '22',
#   'Yearly',
#   'aggregated',
#   'data',
#   'on',
#   'the',
#   'number',
#   'of',
#   'nonduplicate',
#   'clinical',
#   'MRSA',
#   'and',
#   'VRE',
#   'isolates',
#   'causing',
#   'HCAI',
#   'were',
#   'collected',
#   'HCAI',
#   'was',
#   'defined',
#   'according',
#   'to',
#   'the',
#   'National',
#   'Nosocomial',
#   'Infection',
#   'Surveillance',
#   'guidelines',
#   '18',
#   'The',
#   'incidence',
#   'rates',
#   'of',
#   'HCAI',
#   'MRSA',
#   'and',
#   'HCAI',
#   'VRE',
#   'were',
#   'defined',
#   'as',
#   'the',
#   'number',
#   'of',
#   'patients',
#   'with',
#   'HCAI',
#   'MRSA',
#   'and',
#   'HCAI',
#   'VRE',
#   'respectively',
#   'per',
#   '1000',
#   'inpatient',
#   'days',
#   'Data',
#   'on',
#   'annual',
#   'consumption',
#   'defined',
#   'daily',
#   'dose',
#   'DDD',
#   '1000',
#   'inpatient',
#   'days',
#   'of',
#   'glycopeptides',
#   'vancomycin',
#   'and',
#   'teicoplanin',
#   'linezolid',
#   'fusidic',
#   'acid',
#   'tigecycline',
#   'and',
#   'daptomycin',
#   'from',
#   '2000',
#   'to',
#   '2010',
#   'were',
#   'obtained',
#   'from',
#   'the',
#   'pharmacy',
#   'department',
#   'of',
#   'the',
#   'hospital',
#   'Linear',
#   'regression',
#   'analysis',
#   'was',
#   'used',
#   'to',
#   'analyze',
#   'the',
#   'trends',
#   'in',
#   'annual',
#   'consumption',
#   'of',
#   'antimicrobial',
#   'agents',
#   'and',
#   'the',
#   'trends',
#   'in',
#   'incidence',
#   'of',
#   'HCAI',
#   'MRSA',
#   'and',
#   'HCAI',
#   'VRE',
#   'over',
#   'time',
#   'The',
#   'Pearson',
#   'product',
#   'moment',
#   'correlation',
#   'coefficient',
#   'was',
#   'used',
#   'to',
#   'determine',
#   'the',
#   'relationship',
#   'between',
#   'annual',
#   'antibiotic',
#   'consumption',
#   'and',
#   'trends',
#   'in',
#   'resistance',
#   'A',
#   'p',
#   'value',
#   '0',
#   '05',
#   'was',
#   'considered',
#   'statistically',
#   'significant',
#   'In',
#   'general',
#   'the',
#   'use',
#   'of',
#   'each',
#   'antimicrobial',
#   'agent',
#   'varied',
#   'over',
#   'time',
#   'Table',
#   '1',
#   'Overall',
#   'the',
#   'consumption',
#   'of',
#   'teicoplanin',
#   'and',
#   'linezolid',
#   'significantly',
#   'increased',
#   'whereas',
#   'the',
#   'consumption',
#   'of',
#   'vancomycin',
#   'glycopeptides',
#   'including',
#   'vancomycin',
#   'and',
#   'teicoplanin',
#   'tigecycline',
#   'and',
#   'fusidic',
#   'acid',
#   'remained',
#   'stable',
#   'during',
#   'the',
#   'study',
#   'period',
#   'Trend',
#   'in',
#   'HCAI',
#   'due',
#   'to',
#   'MRSA',
#   'and',
#   'VRE',
#   'and',
#   'the',
#   'incidence',
#   'of',
#   'HCAI',
#   'MRSA',
#   'and',
#   'HCAI',
#   'VRE',
#   'during',
#   'the',
#   'period',
#   '2000e2010During',
#   'the',
#   'study',
#   'period',
#   'a',
#   'total',
#   'of',
#   '4657',
#   'nonduplicate',
#   'S',
#   'aureus',
#   'isolates',
#   'and',
#   '4219',
#   'enterococcal',
#   'isolates',
#   'causing',
#   'HCAI',
#   'were',
#   'identified',
#   'Fig',
#   '1A',
#   'shows',
#   'the',
#   'trends',
#   'in',
#   'MRSA',
#   'isolates',
#   'and',
#   'incidence',
#   'of',
#   'HCAI',
#   'MRSA',
#   'There',
#   'was',
#   'a',
#   'significant',
#   'decrease',
#   'in',
#   'the',
#   'incidence',
#   'of',
#   'HCAI',
#   'MRSA',
#   'over',
#   'time',
#   'Fig',
#   '1B',
#   'shows',
#   'the',
#   'trends',
#   'in',
#   'VRE',
#   'isolates',
#   'and',
#   'the',
#   'incidence',
#   'of',
#   'HCAI',
#   'VRE',
#   'A',
#   'significant',
#   'rise',
#   'in',
#   'the',
#   'incidence',
#   'of',
#   'HCAI',
#   'VRE',
#   'over',
#   'time',
#   'was',
#   'noted',
#   'Data',
#   'on',
#   'the',
#   'correlation',
#   'between',
#   'the',
#   'incidence',
#   'of',
#   'HCAI',
#   'MRSA',
#   'the',
#   'incidence',
#   'of',
#   'HCAI',
#   'VRE',
#   'and',
#   'the',
#   'annual',
#   'consumption',
#   'of',
#   'vancomycin',
#   'teicoplanin',
#   'linezolid',
#   'fusidic',
#   'acid',
#   'tigecycline',
#   'and',
#   'daptomycin',
#   'are',
#   'shown',
#   'in',
#   'Tables',
#   '2',
#   'and',
#   '3',
#   'A',
#   'significant',
#   'correlation',
#   'was',
#   'found',
#   'between',
#   'the',
#   'increased',
#   'use',
#   'of',
#   'linezolid',
#   'and',
#   'teicoplanin',
#   'and',
#   'the',
#   'decreased',
#   'prevalence',
#   'of',
#   'MRSA',
#   'By',
#   'contrast',
#   'no',
#   'significant',
#   'correlation',
#   'was',
#   'found',
#   'between',
#   'the',
#   'increased',
#   'use',
#   'of',
#   'vancomycin',
#   'glycopeptides',
#   'vancomycin',
#   'and',
#   'teicoplanin',
#   'tigecycline',
#   'and',
#   'fusidic',
#   'acid',
#   'and',
#   'the',
#   'incidence',
#   'of',
#   'HCAI',
#   'MRSA',
#   'There',
#   'was',
#   'however',
#   'a',
#   'positive',
#   'correlation',
#   'between',
#   'the',
#   'incidence',
#   'of',
#   'HCAI',
#   'VRE',
#   'and',
#   'the',
#   ...])

# %%
dataBag = db.read_text("data/papers_in_json_singleline/*.json").map(json.loads)

# %%
dataBag.take(10000)
# Out:
# ({'paper_id': '000a0fc8bbef80410199e690191dc3076a290117',
#   'cose': 'ajjajajaja'},)

# %%
! ls data/papers_in_json_singleline/*.json > converted_json.txt

# %%
with open("converted_json.txt") as infile:
    content= readlines(infile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-215-421de291297a> in <module>
#       1 with open("converted_json.txt") as infile:
# ----> 2     content= readlines(infile)
#
# NameError: name 'readlines' is not defined

# %%
import nltk
from nltk.corpus import stopwords
import string

3


stop = set(stopwords.words('english'))

text1 = texts.take(1)[0]
text_tokens = word_tokenize(text)

print(text_tokens)

text_clean = [t for t in text_tokens if t not in stop and t not in string.punctuation]
print(string.punctuation)
# Out:
# ['Plasmodium', 'falciparum', ',', 'which', 'causes', 'malignant', 'malaria', 'such', 'as', 'cerebral', 'malaria', '(', 'CM', ')', 'or', 'pregnancy-associated', 'malaria', '(', 'PAM', ')', '[', '1', ',', '2', ']', ',', 'is', 'the', 'cause', 'of', 'death', 'to', '435,000', 'individuals', 'annually', '[', '3', ']', '.', 'Plasmodium', 'falciparum', 'erythrocyte', 'membrane', 'protein', '1', '(', 'PfEMP1', ')', ',', 'which', 'is', 'encoded', 'by', 'the', 'var', 'gene', 'family', 'comprising', 'approximately', '60', 'members', ',', 'is', 'the', 'major', 'virulence', 'factor', 'involved', 'in', 'the', 'antigenic', 'variation', 'and', 'clinical', 'pathogenicity', 'of', 'falciparum', 'malaria', '[', '4', ',', '5', ']', '.', 'It', 'is', 'remarkable', 'that', 'the', 'expression', 'of', 'var', 'family', 'members', 'is', 'mutually', 'exclusive', '.', 'For', 'each', 'parasite', 'at', 'a', 'time', ',', 'only', 'one', 'or', 'a', 'few', 'var', 'genes', 'are', 'expressed', ',', 'while', 'the', 'remaining', 'members', 'are', 'silenced', '[', '6', ',', '7', ']', '.', 'In', 'each', 'generation', ',', 'P.', 'falciparum', 'is', 'able', 'to', 'express', 'different', 'var', 'genes', ',', 'and', 'the', 'switches', 'in', 'var', 'gene', 'expression', 'lead', 'to', 'antigenic', 'variation', 'of', 'PfEMP1', ',', 'which', 'results', 'in', 'immune', 'evasion', 'and', 'chronic', 'infection', '[', '8', ']', '[', '9', ']', '[', '10', ']', '[', '11', ']', '.', 'This', 'process', 'has', 'proven', 'to', 'be', 'mediated', 'by', 'epigenetic', 'mechanisms', ',', 'including', 'chromatin', 'modification', ',', 'nuclear', 'architecture', 'and', 'gene', 'relocation', '[', '12', ',', '13', ']', '.It', 'has', 'been', 'shown', 'that', 'the', 'single', 'active', 'var', 'gene', 'is', 'enriched', 'in', 'euchromatic', 'modifications', ',', 'such', 'as', 'histone', '3', 'lysine', '9', 'acetylation', '(', 'H3K9ac', ')', 'and', 'histone', '3', 'lysine', '4', 'trimethylation', '(', 'H3K4me3', ')', ',', 'particularly', 'near', 'the', 'transcriptional', 'start', 'site', '(', 'TSS', ')', '[', '14', ']', ',', 'while', 'the', 'silent', 'var', 'genes', 'are', 'usually', 'enriched', 'in', 'the', 'heterochromatin', 'marker', '(', 'histone', '3', 'lysine9', 'trimethylation', ',', 'H3K9me3', ')', 'in', 'the', "5'UTR", 'or', 'the', 'coding', 'sequence', '[', '14', ']', '[', '15', ']', '[', '16', ']', '[', '17', ']', '.', 'In', 'this', 'process', ',', 'histone', 'modifying', 'enzymes', 'such', 'as', 'PfMYST', ',', 'PfGCN5', ',', 'PfSIR2', 'and', 'PfSET', ',', 'have', 'been', 'considered', 'important', 'for', 'epigenetic', 'control', 'of', 'reversible', 'histone', 'modifications', ',', 'according', 'to', 'previous', 'studies', '[', '12', ',', '13', ']', '.', 'PfMYST', ',', 'a', 'putative', 'histone', 'acetyltransferases', '(', 'HATs', ')', 'in', 'P.', 'falciparum', ',', 'is', 'capable', 'of', 'acetylating', 'multiple', 'lysines', 'on', 'H4', '[', '18', ',', '19', ']', ',', 'while', 'an', 'orthologue', 'of', 'the', 'yeast', 'HAT', 'PfGCN5', 'influences', 'acetylation', 'of', 'H3K9', 'and', 'K14', ',', 'both', 'are', 'essential', 'marks', 'of', 'gene', 'activation', '[', '18', ',', '20', ']', '.', 'Two', 'paralogues', 'of', 'the', 'class', 'III', 'HDAC', '(', 'histone', 'deacetylases', ')', 'Sir2', ',', 'play', 'key', 'roles', 'in', 'maintaining', 'heterochromatin', 'and', 'mutually', 'exclusive', 'var', 'gene', 'expression', '[', '15', ',', '21', ',', '22', ']', '.', 'PfSir2A', 'deacetylates', 'H3K9ac', ',', 'H3K14ac', 'and', 'H4K16ac', '[', '23', ']', ',', 'and', 'is', 'more', 'important', 'in', 'silencing', 'subtelomeric', 'var', 'genes', 'such', 'as', 'upsA-', ',', 'upsEand', 'upsC-subtype', 'vars', '.', 'In', 'contrast', ',', 'PfSir2B', 'silences', 'upsB', 'vars', '[', '22', ']', '.', 'Furthermore', ',', 'a', 'total', 'of', 'ten', 'P.', 'falciparum', 'histone', 'lysine', 'methyltransferases', '(', 'HKMTs', ')', 'belonging', 'to', 'the', 'SET', 'domain', 'family', 'have', 'been', 'found', 'in ...
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
import nltk
from nltk.corpus import stopwords
import string

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/alessandro/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
from nltk.corpus import stopwords
import string

with open('moby.txt', 'r') as f:
    moby_raw = f.read()
    stop = set(stopwords.words('english'))
    moby_tokens = nltk.word_tokenize(moby_raw)
    text_no_stop_words_punct = [t for t in moby_tokens if t not in stop or t not in string.punctuation]

    print(text_no_stop_words_punct)
